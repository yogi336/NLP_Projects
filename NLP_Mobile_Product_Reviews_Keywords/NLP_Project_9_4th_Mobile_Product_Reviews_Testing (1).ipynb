# %%
### NLP_Project_9_4th_Mobile_Product_Reviews_Testing.ipynb

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.6/dist-packages (3.6.0)
# Requirement already satisfied: smart-open>=1.2.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (2.2.0)
# Requirement already satisfied: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.15.0)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.18.5)
# Requirement already satisfied: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.2.1->gensim) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.2.1->gensim) (1.24.3)

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

review = pd.read_json('/content/drive/My Drive/NLP/Cell_Phones_and_Accessories.json')

# %%
review.head()
# Out:
#    Rating  Rev_verify  Review_Date  ... Review_timestamp Useful Prod_img
# 0       5        True   09 1, 2015  ...       1441065600   None     None
# 1       5        True   01 9, 2016  ...       1452297600   None     None
# 2       5        True  04 21, 2013  ...       1366502400   None     None
# 3       3        True  02 27, 2013  ...       1361923200      3     None
# 4       4        True  12 19, 2013  ...       1387411200   None     None
#
# [5 rows x 11 columns]

# %%
review.isnull().values.any()
# Out:
# True

# %%
print(review['Review'].isnull().values.any())
print(review['Rev_summ'].isnull().values.any())
print(review['IC'].isnull().values.any())
# Out:
# True
# True
# False

# %%
review['Review'] = review['Review'].replace(np.nan, '', regex=True)
review['Rev_summ'] = review['Rev_summ'].replace(np.nan, '', regex=True)
print(review['Review'].isnull().values.any())
print(review['Rev_summ'].isnull().values.any())
# Out:
# False
# False

# %%
review2 = review.copy()
review_combine = review2[['IC','Review','Rev_summ']]

# %%
review_combine.head(2)
# Out:
#            IC  ...              Rev_summ
# 0  B009XD5TPQ  ...  He's very happy with
# 1  B016MF3P3K  ...            Five Stars
#
# [2 rows x 3 columns]

# %%
review_combine.shape
# Out:
# (760450, 3)

# %%
review_combine = review_combine.groupby('IC').agg({'Review':'first',
                               'Rev_summ': ' '.join}).reset_index()

# %%
review_combine.shape
# Out:
# (48134, 3)

# %%
review_combine.head()
# Out:
#            IC  ...                                           Rev_summ
# 0  7508492919  ...  I love it I didn't get the same case that's sh...
# 1  7532385086  ...  A waste of money! htc evo cover better than ex...
# 2  7887421268  ...  Five Stars good deal Five Stars Loved it at fi...
# 3  8199900164  ...           Five Stars I item didn't work Five Stars
# 4  8288853439  ...  GOOD BUY Galaxy S4 Charger LIAR Four Stars gre...
#
# [5 rows x 3 columns]

# %%
review_combine['Review'][567]
# Out:
# "I like PalmOS.  I am used to it; it manages my life effectively.  My wife concurs.  We liked our Treos, but it was time to switch, and the Centro fits well in my wife's hand, particularly.  We both use text-messaging, and a Real Keyboard is a must-have; onscreen virtual keyboards just don't work for us.  The Centro keyboard, though smaller than that of our Treos, is perfectly adequate and easy to use.  In short this is an excellent phone at an unbeatable price.  I now own the successor Pre 2; I like it, but the Centro is my home-phone and I don't see that changing.\n\nI note in passing, this was a case of a company using the full range of seller order-execution and -fulfillment capabilities.  It was a smooth deal."

# %%
review_combine['Rev_summ'][567]
# Out:
# 'A Really Good PalmOS phone stopped working after 1 year software crashes and no tech support'

# %% [markdown]
# **Join two columns (Review & Rev_summ)**

# %%
review_combine_final = review_combine.copy()
review_combine_final['Review_Combine'] =review_combine_final[['Review', 'Rev_summ']].apply(lambda x: ' '.join(x), axis=1)

# %%
review_combine_final.head()
# Out:
#            IC  ...                                     Review_Combine
# 0  7508492919  ...  It is such a good case for a low price. I have...
# 1  7532385086  ...  I was very excited when I first got this case....
# 2  7887421268  ...  Good item Five Stars good deal Five Stars Love...
# 3  8199900164  ...  thank you. Five Stars I item didn't work Five ...
# 4  8288853439  ...  Great ! So far.\nI had this charger before and...
#
# [5 rows x 4 columns]

# %%
review_combine_final['Review'][0]
# Out:
# "It is such a good case for a low price. I have it on right now and never had any problems with it besides losing about 2 stones since my purchase because I'm rough with it. I recommend it."

# %%
review_combine_final['Rev_summ'][0]
# Out:
# "I love it I didn't get the same case that's shown in the ... Pretty! 1 Cute! Cute Bing,Bling!! love it cute but tightt Four Stars Crystal Bow case Cute Great Gift i love it Invisible case ITS ADORABLE GONNA ORDER THE REST. Love this case! BEAUTIFUL Luv luv luv sara I can't stop using this case! Bling cute Bling bling for iPhone 4S Bling no worth it Great for price so cute very sparkly Good love this phone cover!!! .... Pretty Cute! amazing Great cheap plastic Its okay 4S PHONE CASE Loves it!!! Great bow case."

# %%
review_combine_final['Review_Combine'][0]
# Out:
# "It is such a good case for a low price. I have it on right now and never had any problems with it besides losing about 2 stones since my purchase because I'm rough with it. I recommend it. I love it I didn't get the same case that's shown in the ... Pretty! 1 Cute! Cute Bing,Bling!! love it cute but tightt Four Stars Crystal Bow case Cute Great Gift i love it Invisible case ITS ADORABLE GONNA ORDER THE REST. Love this case! BEAUTIFUL Luv luv luv sara I can't stop using this case! Bling cute Bling bling for iPhone 4S Bling no worth it Great for price so cute very sparkly Good love this phone cover!!! .... Pretty Cute! amazing Great cheap plastic Its okay 4S PHONE CASE Loves it!!! Great bow case."

# %% [markdown]
# **Text Preprocessing & Tokenization**

# %%
import gensim
# Converts into tokens (Alternative to word_tokenize)
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer,StemmerI

# %%
# writing function for the entire dataset
import pandas as pd
stemmer = SnowballStemmer("english")
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text,pos='v'))

#Tokenize and Lemmatize
def preprocess(text):
    result=[]
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token)>3:
            result.append(lemmatize_stemming(token))
            
    return result

# %%
# Preprocessing the whole document
processed_docs = []
for doc in review_combine_final['Review_Combine']:
    processed_docs.append(preprocess(doc))

# %%
processed_docs
# Out:
# [['good',
#   'case',
#   'price',
#   'right',
#   'problem',
#   'lose',
#   'stone',
#   'purchas',
#   'rough',
#   'recommend',
#   'love',
#   'case',
#   'show',
#   'pretti',
#   'cute',
#   'cute',
#   'bing',
#   'bling',
#   'love',
#   'cute',
#   'tightt',
#   'star',
#   'crystal',
#   'case',
#   'cute',
#   'great',
#   'gift',
#   'love',
#   'invis',
#   'case',
#   'ador',
#   'gonna',
#   'order',
#   'rest',
#   'love',
#   'case',
#   'beauti',
#   'sara',
#   'stop',
#   'case',
#   'bling',
#   'cute',
#   'bling',
#   'bling',
#   'iphon',
#   'bling',
#   'worth',
#   'great',
#   'price',
#   'cute',
#   'spark',
#   'good',
#   'love',
#   'phone',
#   'cover',
#   'pretti',
#   'cute',
#   'amaz',
#   'great',
#   'cheap',
#   'plastic',
#   'okay',
#   'phone',
#   'case',
#   'love',
#   'great',
#   'case'],
#  ['excit',
#   'case',
#   'love',
#   'color',
#   'feel',
#   'start',
#   'notic',
#   'stuff',
#   'hand',
#   'realiz',
#   'rubber',
#   'peel',
#   'right',
#   'phone',
#   'normal',
#   'say',
#   'go',
#   'wast',
#   'money',
#   'cover',
#   'better',
#   'expect',
#   'expect',
#   'star',
#   'star',
#   'love',
#   'product'],
#  ['good',
#   'item',
#   'star',
#   'good',
#   'deal',
#   'star',
#   'love',
#   'great',
#   'plastic',
#   'sued',
#   'star',
#   'case',
#   'exact',
#   'describ',
#   'star',
#   'poor',
#   'quailti',
#   'wrong',
#   'cute',
#   'simpl',
#   'attract',
#   'protector'],
#  ['thank', 'star', 'item', 'work', 'star'],
#  ['great',
#   'charger',
#   'pretti',
#   'good',
#   'year',
#   'fit',
#   'phone',
#   'iphon',
#   'galaxi',
#   'phone',
#   'right',
#   'portal',
#   'judi',
#   'charg',
#   'slower',
#   'charger',
#   'go',
#   'tend',
#   'loos',
#   'firm',
#   'short',
#   'good',
#   'galaxi',
#   'charger',
#   'liar',
#   'star',
#   'great',
#   'poor',
#   'charger',
#   'star',
#   'work',
#   'great',
#   'work',
#   'fine',
#   'great',
#   'rapid',
#   'charger',
#   'star'],
#  ['fit',
#   'short',
#   'defin',
#   'recommend',
#   'price',
#   'right',
#   'charger',
#   'samsung',
#   'fast',
#   'charg',
#   'charger',
#   'work',
#   'great',
#   'good',
#   'price',
#   'horribl',
#   'star',
#   'stop',
#   'work',
#   'work',
#   'good',
#   'power',
#   'phone',
#   'turn',
#   'charg',
#   'easi',
#   'good',
#   'light',
#   'duti',
#   'failur',
#   'star',
#   'work',
#   'great',
#   'star',
#   'star',
#   'great',
#   'great',
#   'charger',
#   'star',
#   'star',
#   'insuper',
#   'good',
#   'charger',
#   'work',
#   'great',
#   'star',
#   'mess',
#   'charg',
#   'wall',
#   'charger',
#   'star',
#   'star',
#   'charg',
#   'star',
#   'work',
#   'expect'],
#  ['perfect',
#   'note',
#   'backup',
#   'charger',
#   'chage',
#   'samsung',
#   'nite',
#   'fast',
#   'white',
#   'factori',
#   'charger',
#   'perfect',
#   'backup',
#   'charger',
#   'compani',
#   'good',
#   'long',
#   'spare',
#   'charger',
#   'long',
#   'cord',
#   'work',
#   'origin',
#   'come',
#   'phone',
#   'good',
#   'charger',
#   'long',
#   'cord'],
#  ['charger',
#   'specif',
#   'long',
#   'term',
#   'usag',
#   'plug',
#   'remov',
#   'daili',
#   'connect',
#   'snug',
#   'month',
#   'daili',
#   'short',
#   'lifespan',
#   'serv',
#   'purpos',
#   'work',
#   'great',
#   'smartphon',
#   'charger',
#   'exact',
#   'like',
#   'charger',
#   'receiv',
#   'telephon',
#   'work',
#   'star',
#   'good',
#   'work',
#   'star',
#   'qualiti',
#   'star',
#   'good',
#   'produc',
#   'work',
#   'great',
#   'star',
#   'describ',
#   'unfortun',
#   'item',
#   'work',
#   'fine',
#   'nice',
#   'think',
#   'expect',
#   'star',
#   'star',
#   'star',
#   'great',
#   'total',
#   'recommend',
#   'travel',
#   'charger',
#   'great',
#   'product',
#   'star',
#   'work',
#   'star',
#   'work',
#   'like',
#   'origin',
#   'star',
#   'good',
#   'extra',
#   'room',
#   'work',
#   'cabl',
#   'small',
#   'star',
#   'star',
#   'star',
#   'star',
#   'wall',
#   'adapt',
#   'quick',
#   'chager',
#   'state',
#   'micro',
#   'useless',
#   'quick',
#   'perfect',
#   'break',
#   'month',
#   'jean',
#   'review',
#   'awesom',
#   'work',
#   'expect',
#   'star'],
#  ['nice',
#   'case',
#   'print',
#   'start',
#   'fade',
#   'peel',
#   'use',
#   'star',
#   'work',
#   'great',
#   'great',
#   'case',
#   'case'],
#  ['final',
#   'actual',
#   'work',
#   'samsung',
#   'note',
#   'charg',
#   'fast',
#   'satisfi',
#   'great',
#   'simpl',
#   'charger',
#   'output',
#   'perfect',
#   'work',
#   'great',
#   'quick',
#   'charg',
#   'star',
#   'junk',
#   'good',
#   'star',
#   'star',
#   'star',
#   'star',
#   'nice'],
#  ['promis',
#   'normal',
#   'start',
#   'charg',
#   'leav',
#   'phone',
#   'die',
#   'mayb',
#   'charg',
#   'grip',
#   'slipperi',
#   'phone',
#   'add',
#   'extra',
#   'length',
#   'phone',
#   'bulk',
#   'decent',
#   'case',
#   'star',
#   'take',
#   'forev',
#   'recharg',
#   'case',
#   'plug',
#   'surpris',
#   'slimmer',
#   'lighter',
#   'expect',
#   'love',
#   'exact',
#   'describ',
#   'thank',
#   'guy',
#   'great',
#   'feel',
#   'case',
#   'charg',
#   'case',
#   'star',
#   'deliv',
#   'extra',
#   'power',
#   'need',
#   'star',
#   'iight',
#   'guess'],
#  ['product',
#   'charg',
#   'describ',
#   'plastic',
#   'qualiti',
#   'suspect',
#   'piec',
#   'break',
#   'work',
#   'workmanship',
#   'materi',
#   'drop',
#   'phone',
#   'okay',
#   'drop',
#   'sure',
#   'product',
#   'charg',
#   'describ',
#   'plastic',
#   'qualiti',
#   'suspect',
#   'high',
#   'pitch',
#   'gift',
#   'powerbear',
#   'iphon',
#   'batteri',
#   'case',
#   'clunki',
#   'work',
#   'speaker',
#   'jack',
#   'photo',
#   'flashlight'],
#  ['charg',
#   'phone',
#   'cover',
#   'time',
#   'phone',
#   'fall',
#   'easili',
#   'junk',
#   'work',
#   'great',
#   'amaz',
#   'case',
#   'save',
#   'life',
#   'need',
#   'get',
#   'product'],
#  ['buy',
#   'children',
#   'phone',
#   'love',
#   'dead',
#   'batteri',
#   'excus',
#   'longer',
#   'work',
#   'thank',
#   'powerbear',
#   'love',
#   'dead',
#   'batteri',
#   'excus',
#   'excel',
#   'product',
#   'function',
#   'easi',
#   'nice',
#   'great',
#   'batteri',
#   'case',
#   'good',
#   'mophi',
#   'sorri',
#   'powerbear',
#   'nice',
#   'case',
#   'suit',
#   'need',
#   'perfect',
#   'robser'],
#  ['buy',
#   'fantast',
#   'discharg',
#   'hour',
#   'activ',
#   'mean',
#   'last',
#   'week',
#   'charg',
#   'unfortun',
#   'past',
#   'month',
#   'rapid',
#   'degrad',
#   'discharg',
#   'hour',
#   'afternoon',
#   'wors',
#   'previous',
#   'batteri',
#   'phone',
#   'year',
#   'disappoint',
#   'batteri',
#   'long',
#   'bulki',
#   'work',
#   'power',
#   'think',
#   'star',
#   'that',
#   'pretti',
#   'good',
#   'good',
#   'batteri',
#   'case',
#   'star',
#   'great',
#   'valu',
#   'awesom',
#   'warranti',
#   'worth',
#   'price',
#   'disappoint',
#   'powerbear',
#   'extend',
#   'batteri',
#   'case',
#   'great',
#   'product',
#   'slipperi',
#   'good',
#   'batteri',
#   'extend',
#   'phone',
#   'life',
#   'perfect',
#   'batteri',
#   'last',
#   'forev',
#   'star',
#   'star',
#   'light',
#   'great',
#   'technic',
#   'better',
#   'stock',
#   'batteri',
#   'day',
#   'need',
#   'recharg',
#   'star',
#   'packag',
#   'perfect',
#   'condit',
#   'content',
#   'complet',
#   'promis',
#   'work',
#   'great',
#   'great',
#   'batteri',
#   'life',
#   'beat',
#   'batteri',
#   'accessori',
#   'price',
#   'love',
#   'batteri',
#   'great',
#   'sustain',
#   'batteri',
#   'life',
#   'great',
#   'zero',
#   'lemon',
#   'charg',
#   'hold',
#   'good',
#   'batteri',
#   'batteri',
#   'work',
#   'cover',
#   'littl',
#   'better',
#   'star',
#   'good',
#   'nice',
#   'worri',
#   'batteri',
#   'die',
#   'excel',
#   'batteri',
#   'star',
#   'star',
#   'good',
#   'anticip',
#   'aw',
#   'batteri',
#   'excel',
#   'batteri',
#   'look',
#   'get',
#   'grip',
#   'tape',
#   'littl',
#   'better',
#   'work',
#   'great',
#   'hold',
#   'charg',
#   'save',
#   'money',
#   'anker',
#   'zerolemon',
#   'product',
#   'good',
#   'valu',
#   'money',
#   'spend',
#   'final',
#   'charg',
#   'great',
#   'case',
#   'good',
#   'product',
#   'price',
#   'star',
#   'liber',
#   'experi',
#   'star',
#   'star',
#   'review',
#   'user',
#   'star',
#   'star',
#   'great',
#   'safe',
#   'durabl',
#   'love',
#   'maintain',
#   'power',
#   'longer',
#   'good',
#   'haven',
#   'real',
#   'issu',
#   'vase',
#   'total',
#   'love',
#   'sure',
#   'correct',
#   'great',
#   'improv',
#   'bulki',
#   'love',
#   'high',
#   'hop',
#   'qualiti'],
#  ['great',
#   'product',
#   'fast',
#   'deliveri',
#   'love',
#   'extend',
#   'batteri',
#   'life',
#   'come',
#   'cabl',
#   'charg',
#   'case',
#   'need',
#   'micro',
#   'cabl',
#   'great',
#   'product',
#   'fast',
#   'deliveri',
#   'small',
#   'compact',
#   'power',
#   'love',
#   'love',
#   'love',
#   'beat',
#   'valu',
#   'price',
#   'extra',
#   'batteri',
#   'help',
#   'prolong',
#   'batteri',
#   'life',
#   'satisfi',
#   'recommend'],
#  ['graet',
#   'charg',
#   'quick',
#   'graet',
#   'charg',
#   'quick',
#   'star',
#   'star',
#   'star'],
#  ['want',
#   'charger',
#   'chanc',
#   'chanc',
#   'plug',
#   'phone',
#   'charg',
#   'charg',
#   'hour',
#   'charg',
#   'regular',
#   'charger',
#   'charg',
#   'phone',
#   'minut',
#   'charg',
#   'charger',
#   'hour',
#   'stand',
#   'origin',
#   'review',
#   'charger',
#   'misrepres',
#   'fals',
#   'advertis',
#   'charger',
#   'look',
#   'faster',
#   'charg',
#   'take',
#   'minut',
#   'charg',
#   'batteri',
#   'work',
#   'charg',
#   'phone',
#   'fine',
#   'faster',
#   'charger',
#   'purchas',
#   'advertis',
#   'charg',
#   'faster',
#   'fact',
#   'think',
#   'slower',
#   'consid',
#   'time',
#   'take',
#   'charg',
#   'batteri',
#   'buy',
#   'actual',
#   'work',
#   'faster',
#   'possibl',
#   'receiv',
#   'advertis',
#   'hop',
#   'charger',
#   'live',
#   'hype',
#   'go',
#   'charger',
#   'buy',
#   'actual',
#   'charg',
#   'faster',
#   'expens',
#   'extra',
#   'plug',
#   'cord',
#   'spare',
#   'charger',
#   'cord',
#   'buy',
#   'return',
#   'fool',
#   'faster',
#   'charger',
#   'quick',
#   'charger',
#   'excel',
#   'charger'],
#  ['extern',
#   'batteri',
#   'fulli',
#   'charg',
#   'shut',
#   'intermitt',
#   'black',
#   'tape',
#   'come',
#   'super',
#   'glue',
#   'black',
#   'tape',
#   'come',
#   'super',
#   'glue',
#   'star',
#   'star',
#   'star',
#   'star',
#   'good',
#   'good',
#   'phone'],
#  ['monthish',
#   'charg',
#   'get',
#   'shorter',
#   'shorter',
#   'tri',
#   'kill',
#   'batteri',
#   'fulli',
#   'recharg',
#   'help',
#   'overal',
#   'longer',
#   'charg',
#   'origin',
#   'star',
#   'monthish',
#   'defect',
#   'batteri',
#   'wast',
#   'money',
#   'work',
#   'star',
#   'worth',
#   'extra',
#   'bulk',
#   'batteri',
#   'good',
#   'long',
#   'last',
#   'charg',
#   'intermitt',
#   'stop',
#   'work',
#   'strong',
#   'power',
#   'star',
#   'useless',
#   'happi',
#   'result',
#   'star',
#   'star',
#   'reckon',
#   'give',
#   'extra',
#   'power',
#   'awesom',
#   'batteri',
#   'great',
#   'item',
#   'notic',
#   'longer',
#   'batteri',
#   'life',
#   'keep',
#   'run',
#   'singl',
#   'charg',
#   'final',
#   'phone',
#   'power',
#   'good'],
#  ['honest',
#   'look',
#   'better',
#   'pictur',
#   'materi',
#   'look',
#   'poor',
#   'color',
#   'white',
#   'pictur',
#   'durabl',
#   'attent',
#   'getter',
#   'cute',
#   'case',
#   'star'],
#  ['cute',
#   'case',
#   'extrrem',
#   'hard',
#   'guess',
#   'good',
#   'thing',
#   'secur',
#   'phone',
#   'case',
#   'drop',
#   'phone',
#   'cute',
#   'struggl',
#   'awesom',
#   'beauti',
#   'case',
#   'quick',
#   'shipment',
#   'stirdi',
#   'stylish',
#   'case',
#   'absolut',
#   'beauti',
#   'case',
#   'stay',
#   'blue',
#   'vine',
#   'case',
#   'favorit',
#   'phone',
#   'case',
#   'good',
#   'invest',
#   'star',
#   'beauti'],
#  ['look',
#   'work',
#   'great',
#   'fraction',
#   'price',
#   'store',
#   'look',
#   'work',
#   'great',
#   'fraction',
#   'price',
#   'store',
#   'star',
#   'perfect',
#   'star',
#   'hawaiian',
#   'flower',
#   'hard',
#   'casefor',
#   'octan',
#   'beauti',
#   'star'],
#  ['excel',
#   'star',
#   'star',
#   'work',
#   'star',
#   'star',
#   'work',
#   'better',
#   'wireless',
#   'version',
#   'wireless',
#   'version'],
#  ['good', 'star', 'work', 'great', 'samsung', 'etern', 'accessori', 'export'],
#  ['good',
#   'product',
#   'cabl',
#   'work',
#   'perfect',
#   'like',
#   'cabl',
#   'good',
#   'work',
#   'kinda',
#   'generic',
#   'cabl',
#   'work',
#   'blackberri',
#   'plug',
#   'blackberri',
#   'chase',
#   'high',
#   'qualiti',
#   'good',
#   'valu'],
#  ['purchas',
#   'cabl',
#   'cheap',
#   'good',
#   'review',
#   'know',
#   'peopl',
#   'get',
#   'cabl',
#   'work',
#   'buy',
#   'function',
#   'proper',
#   'palm',
#   'best',
#   'charg',
#   'entir',
#   'time',
#   'charg',
#   'complain',
#   'unknown',
#   'devic',
#   'instal',
#   'driver',
#   'work',
#   'beauti',
#   'origin',
#   'cabl',
#   'set',
#   'work',
#   'charg',
#   'cabl',
#   'fail',
#   'slight',
#   'differ',
#   'make',
#   'believ',
#   'differ',
#   'flaw',
#   'tri',
#   'wife',
#   'palm',
#   'pixi',
#   'differ',
#   'comput',
#   'fail',
#   'look',
#   'attempt',
#   'purchas',
#   'cabl',
#   'palm',
#   'devic',
#   'buy',
#   'work',
#   'cheap',
#   'work',
#   'perfect',
#   'work',
#   'star',
#   'good',
#   'palm',
#   'cabl',
#   'work',
#   'good',
#   'qualiti',
#   'cabl',
#   'charg',
#   'connect',
#   'spare',
#   'palm',
#   'charg',
#   'cabl',
#   'star'],
#  ['love',
#   'recommend',
#   'love',
#   'work',
#   'star',
#   'standard',
#   'microusb',
#   'cabl',
#   'blackberri'],
#  ['trust',
#   'accessori',
#   'phone',
#   'have',
#   'luck',
#   'aftermarket',
#   'product',
#   'cheaper',
#   'cheap',
#   'expens',
#   'trust',
#   'accessori',
#   'phone',
#   'compat',
#   'dare',
#   'work',
#   'droid',
#   'incred',
#   'exact',
#   'want',
#   'good',
#   'qualiti',
#   'cabl'],
#  ['charger',
#   'work',
#   'suppos',
#   'charg',
#   'phone',
#   'love',
#   'nifti',
#   'featur',
#   'have',
#   'cabl',
#   'hang',
#   'willi',
#   'nilli',
#   'pull',
#   'work',
#   'fast',
#   'phone',
#   'connect',
#   'proper',
#   'push',
#   'button',
#   'cord',
#   'tighten',
#   'work',
#   'better',
#   'issu',
#   'problem',
#   'think',
#   'bang',
#   'buck',
#   'purchas',
#   'need',
#   'great',
#   'product',
#   'money',
#   'star',
#   'star',
#   'worth',
#   'good',
#   'awesom',
#   'recharg'],
#  ['purchas',
#   'nuvi',
#   'deliveri',
#   'truck',
#   'includ',
#   'suction',
#   'soon',
#   'useless',
#   'month',
#   'constant',
#   'chang',
#   'vehicl',
#   'thank',
#   'purchas',
#   'suggest',
#   'seller',
#   'discov',
#   'friction',
#   'mount',
#   'perfect',
#   'nuvi',
#   'frequent',
#   'vehicl',
#   'simpli',
#   'remov',
#   'vehicl',
#   'prevent',
#   'theft',
#   'mobil',
#   'enhanc',
#   'work',
#   'garmin'],
#  ['break',
#   'super',
#   'easili',
#   'work',
#   'star',
#   'item',
#   'work',
#   'describ',
#   'love',
#   'clasp',
#   'strong',
#   'conveni',
#   'work',
#   'wok',
#   'great',
#   'last',
#   'year',
#   'cheap',
#   'hack',
#   'person',
#   'star',
#   'star',
#   'great',
#   'littl',
#   'stereo',
#   'remot',
#   'keeper',
#   'creat',
#   'belt',
#   'case',
#   'smartphon',
#   'comfort',
#   'poor',
#   'qualiti',
#   'star',
#   'star',
#   'good',
#   'clip',
#   'perfect',
#   'star',
#   'cheap'],
#  ['freespeak',
#   'bluetooth',
#   'phone',
#   'love',
#   'bluetooth',
#   'multi',
#   'adapt',
#   'bluetooth',
#   'phone',
#   'work',
#   'great',
#   'phone',
#   'support',
#   'headset',
#   'initi',
#   'answer',
#   'voic',
#   'dial',
#   'end',
#   'pain',
#   'go',
#   'headset',
#   'final',
#   'enjoy',
#   'true',
#   'cordless',
#   'freedom',
#   'note',
#   'notic',
#   'rang',
#   'jabra',
#   'multi',
#   'adapt',
#   'adapt',
#   'good',
#   'feet',
#   'rang',
#   'phone',
#   'adapt',
#   'headset',
#   'get',
#   'mayb',
#   'feet',
#   'appar',
#   'sonyericsson',
#   'implement',
#   'bluetooth',
#   'fault',
#   'headset',
#   'think',
#   'belt',
#   'clip',
#   'charger',
#   'need',
#   'sort',
#   'posit',
#   'lock',
#   'prevent',
#   'lose',
#   'headset',
#   'light',
#   'weight',
#   'make',
#   'littl',
#   'nois',
#   'drop',
#   'secur',
#   'posit',
#   'charg',
#   'awesom',
#   'headset',
#   'confirm',
#   'work',
#   'work',
#   'hop',
#   'qualiti',
#   'avoid'],
#  ['sheet',
#   'paper',
#   'includ',
#   'purchas',
#   'activ',
#   'phone',
#   'includ',
#   'inform',
#   'phone',
#   'section',
#   'troubleshoot',
#   'issu',
#   'list',
#   'contact',
#   'have',
#   'problem',
#   'review',
#   'paper',
#   'like',
#   'seller',
#   'get',
#   'start',
#   'guid',
#   'wireless',
#   'servic',
#   'star',
#   'okay',
#   'star',
#   'uhhhh',
#   'insert',
#   'suppos',
#   'rat',
#   'star',
#   'know',
#   'review',
#   'star',
#   'use',
#   'perfect',
#   'star',
#   'work',
#   'free',
#   'good',
#   'phone',
#   'star',
#   'star',
#   'star'],
#  ['buy',
#   'phone',
#   'day',
#   'awesom',
#   'pretti',
#   'cool',
#   'cool',
#   'featur',
#   'bluetooth',
#   'card',
#   'includ',
#   'upgrad',
#   'larg',
#   'screen',
#   'play',
#   'midi',
#   'drop',
#   'connect',
#   'ton',
#   'softwar',
#   'run',
#   'symbian',
#   'lot',
#   'program',
#   'game',
#   'instal',
#   'instal',
#   'activ',
#   'desk',
#   'replac',
#   'desktop',
#   'theme',
#   'organ',
#   'agilemesseng',
#   'support',
#   'yahoo',
#   'extend',
#   'profil',
#   'let',
#   'custim',
#   'differnet',
#   'profil',
#   'come',
#   'long',
#   'check',
#   'yahoo',
#   'group',
#   'lot',
#   'good',
#   'background',
#   'game',
#   'rington',
#   'replac',
#   'browser',
#   'opera',
#   'netfront',
#   'screen',
#   'saver',
#   'remot',
#   'softwar',
#   'gameboy',
#   'emul',
#   'haven',
#   'tri',
#   'hell',
#   'movi',
#   'download',
#   'watch',
#   'unit',
#   'larger',
#   'card',
#   'negat',
#   'featur',
#   'batteri',
#   'life',
#   'usign',
#   'bluetooth',
#   'excessivli',
#   'strang',
#   'keypad',
#   'layout',
#   'bluetooth',
#   'learn',
#   'curv',
#   'slow',
#   'boot',
#   'second',
#   'connect',
#   'bluetooth',
#   'headach',
#   'set',
#   'have',
#   'problem',
#   'connect',
#   'clie',
#   'need',
#   'special',
#   'driver',
#   'internet',
#   'point',
#   'check',
#   'mail',
#   'brows',
#   'chat',
#   'yahoo',
#   'messeng',
#   'hard',
#   'keypad',
#   'predic',
#   'input',
#   'help',
#   'mobli',
#   'coverag',
#   'citi',
#   'interst',
#   'like',
#   'gadget',
#   'palm',
#   'phone',
#   'nerd',
#   'heaven',
#   'pretti',
#   'good',
#   'phone',
#   'phone',
#   'display',
#   'tribut',
#   'star',
#   'entri',
#   'level',
#   'phone',
#   'smart',
#   'flaw',
#   'annoy',
#   'work',
#   'good',
#   'phone',
#   'poor',
#   'mobil',
#   'servic'],
#  ['buy',
#   'phone',
#   'june',
#   'wife',
#   'sign',
#   'famili',
#   'plan',
#   'save',
#   'month',
#   'share',
#   'slight',
#   'minut',
#   'famili',
#   'member',
#   'rebat',
#   'arriv',
#   'week',
#   'promis',
#   'send',
#   'pictur',
#   'babi',
#   'mobil',
#   'zone',
#   'servic',
#   'cool',
#   'night',
#   'card',
#   'brewer',
#   'basebal',
#   'game',
#   'downtown',
#   'loui',
#   'take',
#   'second',
#   'video',
#   'scott',
#   'rolen',
#   'home',
#   'send',
#   'video',
#   'wife',
#   'phone',
#   'watch',
#   'mile',
#   'away',
#   'minut',
#   'later',
#   'check',
#   'work',
#   'email',
#   'account',
#   'brows',
#   'news',
#   'espn',
#   'news',
#   'news',
#   'stoplight',
#   'work',
#   'countri',
#   'vacat',
#   'trip',
#   'juli',
#   'lake',
#   'ozark',
#   'yahoo',
#   'account',
#   'kind',
#   'alert',
#   'break',
#   'news',
#   'weather',
#   'phone',
#   'email',
#   'address',
#   'friend',
#   'famili',
#   'send',
#   'email',
#   'bluetooth',
#   'capabl',
#   'use',
#   'sync',
#   'contact',
#   'data',
#   'imac',
#   'regular',
#   'version',
#   'isync',
#   'support',
#   'calendar',
#   'synchron',
#   'wireless',
#   'game',
#   'play',
#   'doom',
#   'star',
#   'trek',
#   'tank',
#   'game',
#   'lot',
#   'doom',
#   'take',
#   'hack',
#   'work',
#   'keyboard',
#   'goofi',
#   'get',
#   'look',
#   'caveat',
#   'sure',
#   'employ',
#   'allow',
#   'camera',
#   'phone',
#   'buy',
#   'free',
#   'phone',
#   'wife',
#   'take',
#   'nokia',
#   'phone',
#   'screen',
#   'strang',
#   'layout'],
#  ['batteri',
#   'pack',
#   'work',
#   'fit',
#   'perfect',
#   'cabl',
#   'connector',
#   'present',
#   'issu',
#   'instal',
#   'great',
#   'replac',
#   'batteri',
#   'pack'],
#  ['antenna',
#   'accord',
#   'schemat',
#   'lower',
#   'phone',
#   'place',
#   'booster',
#   'batteri',
#   'tri',
#   'place',
#   'phone',
#   'remov',
#   'side',
#   'tape',
#   'signal',
#   'wors',
#   'terrib',
#   'galaxi',
#   'junk',
#   'worthless',
#   'work',
#   'star',
#   'like',
#   'benefit',
#   'cell',
#   'phone',
#   'booster',
#   'star',
#   'interfer',
#   'signal',
#   'star',
#   'scam',
#   'star',
#   'soso',
#   'dont',
#   'wast',
#   'money',
#   'sucker',
#   'dang',
#   'star',
#   'star',
#   'weird',
#   'work',
#   'kinda',
#   'help',
#   'booster',
#   'buck',
#   'worth',
#   'improv',
#   'cheep',
#   'phone',
#   'junk',
#   'iphon',
#   'star',
#   'happi',
#   'good',
#   'suck',
#   'star',
#   'worth',
#   'star',
#   'tradiot',
#   'american',
#   'littl',
#   'improv',
#   'remedi',
#   'metal',
#   'roof',
#   'drop',
#   'star',
#   'star',
#   'proof',
#   'put',
#   'market',
#   'cellular',
#   'innov',
#   'booster',
#   'work',
#   'unknown',
#   'qualiti',
#   'wast',
#   'money',
#   'antenna',
#   'booster',
#   'star'],
#  ['mention',
#   'band',
#   'littl',
#   'long',
#   'problem',
#   'good',
#   'activ',
#   'want',
#   'avoid',
#   'get',
#   'sweat',
#   'leather',
#   'band',
#   'good',
#   'activ',
#   'want',
#   'avoid',
#   'get',
#   'sweat',
#   'star',
#   'peopl',
#   'small',
#   'wrist',
#   'great',
#   'band',
#   'awesom',
#   'definit',
#   'long',
#   'nice',
#   'band',
#   'qualiti',
#   'materi',
#   'comfort',
#   'silver',
#   'buckl',
#   'stand',
#   'star',
#   'advertis',
#   'small',
#   'star',
#   'high',
#   'qualiti',
#   'band',
#   'feel',
#   'look',
#   'better',
#   'leather',
#   'band',
#   'come',
#   'moto',
#   'look',
#   'band',
#   'altern',
#   'metal',
#   'sturdi',
#   'lightweight',
#   'option',
#   'weather',
#   'sweat',
#   'resist'],
#  ['fit',
#   'phone',
#   'key',
#   'problem',
#   'float',
#   'leak',
#   'great',
#   'fish',
#   'cano',
#   'trip',
#   'bulki',
#   'get',
#   'work',
#   'great',
#   'love',
#   'rug',
#   'secur',
#   'soft',
#   'pad',
#   'interior',
#   'fit',
#   'wallet',
#   'iphon',
#   'otterbox',
#   'defend',
#   'problem',
#   'better',
#   'expect',
#   'great',
#   'safe',
#   'gnar',
#   'littl',
#   'great',
#   'case',
#   'great',
#   'littl',
#   'otterbox',
#   'great'],
#  ['europ',
#   'phone',
#   'network',
#   'better',
#   'state',
#   'think',
#   'samsung',
#   'current',
#   'best',
#   'softwar',
#   'huge',
#   'nokia',
#   'amaz',
#   'light',
#   'intuit',
#   'great',
#   'audio',
#   'look',
#   'great',
#   'recommend',
#   'reserv',
#   'whatsoev',
#   'best',
#   'phone',
#   'own',
#   'user',
#   'friend',
#   'motorola',
#   'love',
#   'phone',
#   'real',
#   'problem',
#   'good',
#   'phone',
#   'function',
#   'miss',
#   'pretti',
#   'good',
#   'phone',
#   'improv'],
#  ['frank',
#   'high',
#   'expect',
#   'treo',
#   'read',
#   'time',
#   'lead',
#   'releas',
#   'actual',
#   'disappoint',
#   'deserv',
#   'star',
#   'usabl',
#   'pocket',
#   'smart',
#   'phone',
#   'biggest',
#   'gripe',
#   'lie',
#   'keyboard',
#   'small',
#   'minimalist',
#   'easi',
#   'press',
#   'key',
#   'time',
#   'handspr',
#   'say',
#   'best',
#   'design',
#   'thumboard',
#   'believ',
#   'key',
#   'round',
#   'surfac',
#   'hurt',
#   'finger',
#   'type',
#   'littl',
#   'biggest',
#   'problem',
#   'space',
#   'key',
#   'small',
#   'close',
#   'dedic',
#   'number',
#   'key',
#   'extrem',
#   'annoy',
#   'woe',
#   'limit',
#   'lock',
#   'numer',
#   'key',
#   'hold',
#   'number',
#   'shift',
#   'type',
#   'number',
#   'clear',
#   'wasn',
#   'think',
#   'straight',
#   'easier',
#   'type',
#   'accent',
#   'letter',
#   'aren',
#   'english',
#   'punctuat',
#   'plain',
#   'silli',
#   'screen',
#   'small',
#   'view',
#   'angl',
#   'good',
#   'mean',
#   'look',
#   'straight',
#   'hard',
#   'time',
#   'see',
#   'screen',
#   'compar',
#   'silk',
#   'smooth',
#   'screen',
#   'tungsten',
#   'clie',
#   'feel',
#   'crude',
#   'pixel',
#   'plan',
#   'treo',
#   'surf',
#   'prepar',
#   'disappoint',
#   'internet',
#   'speed',
#   'plain',
#   'pathet',
#   'load',
#   'seller',
#   'home',
#   'page',
#   'take',
#   'minut',
#   'bare',
#   'readabl',
#   'layout',
#   'screw',
#   'load',
#   'home',
#   'page',
#   'take',
#   'longer',
#   'pictur',
#   'come',
#   'nice',
#   'reason',
#   'abl',
#   'open',
#   'appl',
#   'homepag',
#   'error',
#   'messag',
#   'page',
#   'msnbc',
#   'work',
#   'fine',
#   'yahoo',
#   'sprint',
#   'home',
#   'page',
#   'good',
#   'thing',
#   'short',
#   'pretti',
#   'disappoint',
#   'implement',
#   'model',
#   'treo',
#   'rumor',
#   'come',
#   'soon',
#   'better',
#   'screen',
#   'improv',
#   'batteri',
#   'life',
#   'probabl',
#   'slow',
#   'internet',
#   'speed',
#   'problem',
#   'network',
#   'treo',
#   'hardwar',
#   'lot',
#   'money',
#   'throw',
#   'away',
#   'feel',
#   'like',
#   'give',
#   'chariti',
#   'recommend',
#   'wait',
#   'generat',
#   'treo',
#   'lot',
#   'hype',
#   'deliveri',
#   'major',
#   'flaw',
#   'devic',
#   'bewar',
#   'perfect',
#   'smart',
#   'devic',
#   'blackberi',
#   'user',
#   'skeptic',
#   'convinc',
#   'thumb',
#   'resolut',
#   'camera',
#   'batteri',
#   'life'],
#  ['chicago',
#   'work',
#   'go',
#   'window',
#   'dozen',
#   'time',
#   'surround',
#   'suburb',
#   'work',
#   'mile',
#   'north',
#   'chicago',
#   'know',
#   'break',
#   'unfortun',
#   'telenav',
#   'compani',
#   'sell',
#   'map',
#   'servic',
#   'nextel',
#   'phone',
#   'charg',
#   'kilobyt',
#   'mysteri',
#   'come',
#   'buck',
#   'month',
#   'addit',
#   'total',
#   'connect',
#   'servic',
#   'nextel',
#   'need',
#   'function',
#   'buck',
#   'month',
#   'kicker',
#   'figur',
#   'hard',
#   'work',
#   'sign',
#   'year',
#   'telenav',
#   'servic',
#   'telenav',
#   'refund',
#   'singl',
#   'dime',
#   'work',
#   'area',
#   'nextel',
#   'tech',
#   'speak',
#   'cancel',
#   'total',
#   'connect',
#   'say',
#   'telenav',
#   'tell',
#   'gaurante',
#   'telenav',
#   'function',
#   'satelllit',
#   'time',
#   'bunch',
#   'fargin',
#   'icehol',
#   'state',
#   'like',
#   'nextel',
#   'servic',
#   'browser',
#   'best',
#   'kind',
#   'info',
#   'peopl',
#   'finder',
#   'equival',
#   'white',
#   'page',
#   'busi',
#   'finder',
#   'movi',
#   'time',
#   'stuff',
#   'snocountri',
#   'tell',
#   'snow',
#   'hill',
#   'america',
#   'nice',
#   'telenav',
#   'work',
#   'rule',
#   'respect',
#   'nextel',
#   'happi',
#   'phone',
#   'cheaper',
#   'model',
#   'get',
#   'better',
#   'signal'],
#  ['travel',
#   'decid',
#   'final',
#   'time',
#   'start',
#   'record',
#   'realiz',
#   'map',
#   'insan',
#   'expens',
#   'read',
#   'good',
#   'review',
#   'decid',
#   'purchas',
#   'regret',
#   'exact',
#   'need',
#   'come',
#   'roll',
#   'mean',
#   'ship',
#   'map',
#   'larg',
#   'pictur',
#   'come',
#   'perfect',
#   'condit',
#   'come',
#   'time',
#   'perfect',
#   'size',
#   'visual',
#   'pleas',
#   'countri',
#   'state',
#   'citi',
#   'lay',
#   'print',
#   'citi',
#   'print',
#   'rough',
#   'estim',
#   'actual',
#   'accur',
#   'abl',
#   'locat',
#   'pin',
#   'wall',
#   'pleas',
#   'hope',
#   'start',
#   'make',
#   'bigger',
#   'one',
#   'travel',
#   'famili',
#   'basement',
#   'happi',
#   'custom',
#   'star',
#   'histori',
#   'class',
#   'grand',
#   'daughter',
#   'need',
#   'best',
#   'great',
#   'qualiti',
#   'better',
#   'price',
#   'good',
#   'offic'],
#  ['ansmann',
#   'charger',
#   'simpli',
#   'take',
#   'guesswork',
#   'charg',
#   'batteri',
#   'simpli',
#   'plug',
#   'stick',
#   'batteri',
#   'matter',
#   'current',
#   'charg',
#   'level',
#   'refresh',
#   'neat',
#   'clean',
#   'strike',
#   'product',
#   'manuel',
#   'write',
#   'german',
#   'simpli',
#   'follow',
#   'color',
#   'code',
#   'charger',
#   'best',
#   'charger',
#   'best',
#   'charger',
#   'own',
#   'huge',
#   'work',
#   'poor',
#   'qualiti',
#   'long',
#   'charger',
#   'need'],
#  ['fit',
#   'handlebar',
#   'size',
#   'tri',
#   'hold',
#   'unit',
#   'secur',
#   'break',
#   'work',
#   'fit',
#   'star',
#   'necessari',
#   'evil',
#   'fit',
#   'perfect',
#   'part',
#   'includ',
#   'great',
#   'wrist',
#   'strap',
#   'holder',
#   'doubt',
#   'perfect',
#   'want',
#   'bicycl'],
#  ['satisfi',
#   'amaz',
#   'work',
#   'deep',
#   'pain',
#   'kink',
#   'take',
#   'longer',
#   'come',
#   'splendid',
#   'worth',
#   'wait',
#   'trust',
#   'worthi',
#   'cent',
#   'review',
#   'usabl',
#   'cute'],
#  ['virgin',
#   'mobil',
#   'best',
#   'prepay',
#   'servic',
#   'provid',
#   'tracfon',
#   'horribl',
#   'minut',
#   'high',
#   'minut',
#   'text',
#   'messag',
#   'think',
#   'receiv',
#   'text',
#   'messag',
#   'tracfon',
#   'virgin',
#   'mobil',
#   'minut',
#   'minut',
#   'minut',
#   'text',
#   'messag',
#   'send',
#   'free',
#   'receiv',
#   'content',
#   'avail',
#   'virginmobileusa',
#   'put',
#   'phone',
#   'rington',
#   'celebr',
#   'voicemail',
#   'greet',
#   'comedi',
#   'central',
#   'content',
#   'play',
#   'month',
#   'cheaper',
#   'cell',
#   'phone',
#   'servic',
#   'provid',
#   'best',
#   'contract',
#   'virgin',
#   'mobil',
#   'prepay',
#   'phone',
#   'servic',
#   'virgin',
#   'mobil',
#   'best',
#   'prepay',
#   'cell',
#   'phone',
#   'servic'],
#  ['palm',
#   'pilot',
#   'year',
#   'case',
#   'beauti',
#   'leather',
#   'durabl',
#   'beauti',
#   'leather',
#   'durabl',
#   'perfect',
#   'protect',
#   'return',
#   'star'],
#  ['work',
#   'great',
#   'hold',
#   'small',
#   'thermomet',
#   'vertic',
#   'degre',
#   'angl',
#   'dash',
#   'read',
#   'sticki',
#   'side',
#   'sticki',
#   'care',
#   'remov',
#   'thing',
#   'like',
#   'cell',
#   'phone',
#   'pull',
#   'dashboard',
#   'stick',
#   'requir',
#   'time',
#   'unstick',
#   'replac',
#   'think',
#   'edg',
#   'curl',
#   'read',
#   'review',
#   'anti',
#   'slip',
#   'star',
#   'star',
#   'sticki',
#   'rubber',
#   'sheet',
#   'dirti',
#   'need',
#   'clean',
#   'work',
#   'advertis',
#   'best',
#   'sticki',
#   'great',
#   'good',
#   'item',
#   'okay',
#   'stick',
#   'dash',
#   'work',
#   'advertis',
#   'sticki',
#   'troubl',
#   'get',
#   'packag',
#   'long',
#   'last',
#   'star',
#   'discontinu',
#   'best',
#   'sticki',
#   'pad',
#   'work',
#   'think',
#   'like',
#   'origin',
#   'one',
#   'like',
#   'bigger',
#   'size',
#   'work',
#   'great',
#   'overs',
#   'perfect',
#   'need',
#   'see',
#   'year',
#   'sticki',
#   'star',
#   'star',
#   'handstand',
#   'make',
#   'best',
#   'sticki',
#   'period',
#   'star',
#   'buy',
#   'item',
#   'alot',
#   'good',
#   'item',
#   'sticki',
#   'hold',
#   'item',
#   'star',
#   'nice'],
#  ['drop',
#   'call',
#   'compani',
#   'guess',
#   'best',
#   'verizon',
#   'cingular',
#   'good',
#   'servic',
#   'work',
#   'worth',
#   'money',
#   'star',
#   'cingular',
#   'year',
#   'contract',
#   'good',
#   'star',
#   'purchas',
#   'cheaper',
#   'star'],
#  ['appreci',
#   'option',
#   'return',
#   'mistaken',
#   'order',
#   'product',
#   'nomin',
#   'star',
#   'yayi',
#   'gover',
#   'fee',
#   'dang',
#   'phone',
#   'compani',
#   'scam',
#   'cool',
#   'gosh',
#   'love',
#   'regulatori',
#   'star',
#   'good',
#   'servic',
#   'star'],
#  ['phone',
#   'candi',
#   'get',
#   'lot',
#   'attent',
#   'ring',
#   'tone',
#   'purs',
#   'vibrat',
#   'ringer',
#   'pocket',
#   'speaker',
#   'phone',
#   'voic',
#   'sound',
#   'muffl',
#   'attract',
#   'that',
#   'sanyo',
#   'come',
#   'earth',
#   'word',
#   'avoid',
#   'star',
#   'reason',
#   'sprint',
#   'nextel',
#   'best'],
#  ['buy',
#   'headset',
#   'girlfriend',
#   'recommend',
#   'cingular',
#   'sale',
#   'moto',
#   'know',
#   'bluetooth',
#   'headset',
#   'time',
#   'opt',
#   'week',
#   'later',
#   'giddi',
#   'like',
#   'candi',
#   'store',
#   'take',
#   'figur',
#   'instal',
#   'headset',
#   'sure',
#   'bluetooth',
#   'headset',
#   'share',
#   'minor',
#   'inconveni',
#   'minor',
#   'inconveni',
#   'button',
#   'nice',
#   'feel',
#   'push',
#   'locat',
#   'tricki',
#   'thing',
#   'like',
#   'replac',
#   'recharg',
#   'batteri',
#   'hate',
#   'headset',
#   'batteri',
#   'longer',
#   'hold',
#   'charg',
#   'regardless',
#   'better',
#   'valu',
#   'thing',
#   'nice',
#   'batteri',
#   'perform',
#   'great',
#   'addit',
#   'bluetooth',
#   'phone',
#   'unit',
#   'comfort',
#   'lack',
#   'durabl',
#   'neat',
#   'concept',
#   'imperfect',
#   'implement',
#   'great',
#   'product',
#   'univers',
#   'communic',
#   'phone',
#   'suck',
#   'fest'],
#  ['item',
#   'perfect',
#   'older',
#   'chevrolet',
#   'pickup',
#   'want',
#   'replac',
#   'speaker',
#   'connector',
#   'work',
#   'perfect',
#   'wire',
#   'splice',
#   'speaker',
#   'instal',
#   'minut',
#   'item',
#   'perfect',
#   'older',
#   'chevrolet',
#   'pickup',
#   'star',
#   'perfect',
#   'blazer'],
#  ['headset',
#   'purchas',
#   'replac',
#   'crappi',
#   'jabra',
#   'freespeak',
#   'small',
#   'unlik',
#   'goldlatern',
#   'bluetrek',
#   'jabra',
#   'hide',
#   'mass',
#   'sit',
#   'right',
#   'outsid',
#   'complet',
#   'inconspicu',
#   'bluetrek',
#   'jabra',
#   'hair',
#   'plus',
#   'bluetooth',
#   'headset',
#   'impress',
#   'peopl',
#   'atttent',
#   'want',
#   'peopl',
#   'attent',
#   'question',
#   'headset',
#   'drawback',
#   'huge',
#   'blue',
#   'like',
#   'light',
#   'take',
#   'piec',
#   'attract',
#   'attent',
#   'headset',
#   'blink',
#   'standbi',
#   'blink',
#   'oper',
#   'blink',
#   'dang',
#   'time',
#   'pass',
#   'work',
#   'pretti',
#   'sound',
#   'littl',
#   'tinni',
#   'pretti',
#   'clear',
#   'unlik',
#   'bluetooth',
#   'headset',
#   'headset',
#   'volum',
#   'oper',
#   'headset',
#   'link',
#   'phone',
#   'volum',
#   'mean',
#   'adjust',
#   'volum',
#   'level',
#   'loud',
#   'good',
#   'good',
#   'complaint',
#   'basic',
#   'batteri',
#   'life',
#   'ugli',
#   'hour',
#   'anchor',
#   'littl',
#   'rigid',
#   'smaller',
#   'smaller',
#   'ear',
#   'long',
#   'jog',
#   'constant',
#   'good',
#   'perform',
#   'expect',
#   'star',
#   'great',
#   'bluetooth',
#   'headset',
#   'poor',
#   'star'],
#  ['gift', 'work', 'star', 'great', 'obo', 'case'],
#  ['stay',
#   'away',
#   'updat',
#   'think',
#   'possibl',
#   'scienc',
#   'increas',
#   'point',
#   'split',
#   'atom',
#   'right',
#   'manag',
#   'split',
#   'leather',
#   'atom',
#   'mere',
#   'dollar',
#   'molecul',
#   'leather',
#   'fannypack',
#   'place',
#   'pack',
#   'pointi',
#   'hard',
#   'tissu',
#   'piec',
#   'paper',
#   'rapid',
#   'tear',
#   'molecul',
#   'leather',
#   'junk',
#   'seller',
#   'stand',
#   'product',
#   'tell',
#   'contact',
#   'manufactur',
#   'yeah',
#   'good',
#   'luck',
#   'like',
#   'care',
#   'singl',
#   'buyer',
#   'sorri',
#   'tell',
#   'year',
#   'great',
#   'current',
#   'paper',
#   'absolut',
#   'wast',
#   'money',
#   'look',
#   'think',
#   'go',
#   'bite',
#   'bullet',
#   'custom',
#   'real',
#   'leather',
#   'black',
#   'leather',
#   'paper',
#   'wear',
#   'fanni',
#   'pack',
#   'year',
#   'kind',
#   'expert',
#   'hand',
#   'durabl',
#   'function',
#   'think',
#   'pack',
#   'hold',
#   'item',
#   'neat',
#   'littl',
#   'larg',
#   'great',
#   'qualiti',
#   'leather',
#   'wear',
#   'hour',
#   'work',
#   'car',
#   'sit',
#   'bend',
#   'perfect',
#   'cheap',
#   'flea',
#   'market',
#   'one',
#   'fall',
#   'apart',
#   'month',
#   'year',
#   'hard',
#   'start',
#   'look',
#   'beat',
#   'year',
#   'constant',
#   'excel',
#   'life',
#   'price',
#   'excel',
#   'product',
#   'edit',
#   'qualiti',
#   'fade',
#   'poor',
#   'qualiti',
#   'product',
#   'amerileath',
#   'black',
#   'fanni',
#   'pack',
#   'need',
#   'leather',
#   'cell',
#   'phone',
#   'fanni',
#   'pack',
#   'burgundi'],
#  ['great',
#   'product',
#   'suppos',
#   'rig',
#   'boat',
#   'power',
#   'work',
#   'like',
#   'charm',
#   'addit',
#   'buy',
#   'male',
#   'lighter',
#   'plug',
#   'solder',
#   'electron',
#   'light',
#   'troll',
#   'motor',
#   'great',
#   'definit',
#   'recommend',
#   'great',
#   'product',
#   'suppos',
#   'star',
#   'solid',
#   'build',
#   'excel',
#   'articl',
#   'satisfi',
#   'qualiti',
#   'time',
#   'deliveri',
#   'mount',
#   'good',
#   'strong',
#   'mount',
#   'come',
#   'like',
#   'dose',
#   'hole',
#   'flang',
#   'star',
#   'star',
#   'nice',
#   'littl',
#   'devic',
#   'great',
#   'plug',
#   'motorcycl',
#   'star',
#   'good',
#   'star',
#   'work',
#   'great',
#   'star',
#   'star',
#   'star',
#   'star',
#   'chines',
#   'junk',
#   'good',
#   'product',
#   'work',
#   'good',
#   'work',
#   'great',
#   'refriger',
#   'staid',
#   'power',
#   'time',
#   'star',
#   'work',
#   'good',
#   'qualiti',
#   'star',
#   'good',
#   'great',
#   'kawasaki',
#   'star',
#   'good',
#   'simpl',
#   'use',
#   'star',
#   'great',
#   'right',
#   'durabl',
#   'cigarett',
#   'socket',
#   'perfect',
#   'add',
#   'socket',
#   'insid',
#   'consol',
#   'runner',
#   'work',
#   'truck',
#   'perfect',
#   'star',
#   'boat',
#   'perfect',
#   'star',
#   'work',
#   'perfect',
#   'boat',
#   'great',
#   'littl',
#   'power',
#   'port',
#   'lighter',
#   'socket',
#   'star',
#   'extern',
#   'work'],
#  ['buy',
#   'phone',
#   'expens',
#   'price',
#   'year',
#   'think',
#   'best',
#   'cingular',
#   'offer',
#   'problem',
#   'tri',
#   'report',
#   'defect',
#   'phone',
#   'wouldn',
#   'hold',
#   'voic',
#   'mail',
#   'cingular',
#   'reprogram',
#   'problem',
#   'button',
#   'chang',
#   'ring',
#   'loud',
#   'silent',
#   'beep',
#   'button',
#   'locat',
#   'accid',
#   'press',
#   'cingular',
#   'phone',
#   'motorola',
#   'rest',
#   'motorola',
#   'phone',
#   'drop',
#   'call',
#   'like',
#   'crazi',
#   'bare',
#   'convers',
#   'endur',
#   'conclus',
#   'drop',
#   'dial',
#   'fail',
#   'happen',
#   'time',
#   'go',
#   'soon',
#   'contract',
#   'cingular',
#   'cingular',
#   'sprint',
#   'discontinu',
#   'phone',
#   'friend',
#   'work',
#   'sprint',
#   'tell',
#   'reason',
#   'discontinu',
#   'phone',
#   'problem',
#   'drop',
#   'call',
#   'ton',
#   'drop',
#   'call',
#   'sprint',
#   'wireless',
#   'dual',
#   'band',
#   'analog',
#   'digit',
#   'work',
#   'suppos',
#   'time',
#   'rang',
#   'drop',
#   'cellular',
#   'phone',
#   'drop',
#   'call',
#   'happen',
#   'probabl',
#   'user',
#   'rotat',
#   'drop',
#   'call',
#   'purpos',
#   'user',
#   'think',
#   'easi',
#   'access',
#   'tower',
#   'like',
#   'isp',
#   'custom',
#   'base',
#   'larg',
#   'server',
#   'capac',
#   'design',
#   'drop',
#   'call',
#   'work',
#   'wast',
#   'time',
#   'love',
#   'mobil',
#   'hate',
#   'motorola',
#   'perfect',
#   'attract',
#   'use'],
#  ['enjoy',
#   'pod',
#   'fit',
#   'perfect',
#   'tri',
#   'kind',
#   'self',
#   'adjust',
#   'pod',
#   'great',
#   'sound',
#   'awesom',
#   'price',
#   'product',
#   'return',
#   'send',
#   'defect',
#   'product',
#   'good',
#   'sound',
#   'comfort',
#   'motorola',
#   'bud',
#   'satisfi',
#   'glad',
#   'star',
#   'star',
#   'nice',
#   'light',
#   'weight',
#   'headset',
#   'excel',
#   'control',
#   'worst',
#   'headset',
#   'bother',
#   'headset',
#   'sound',
#   'tinni',
#   'loud',
#   'horribl',
#   'sound',
#   'reason',
#   'discreet',
#   'wireless',
#   'headset',
#   'work',
#   'star',
#   'want',
#   'like',
#   'star',
#   'suck',
#   'bluetooth',
#   'headphon',
#   'best',
#   'neckband',
#   'earbud',
#   'own',
#   'star',
#   'star',
#   'drawback',
#   'list',
#   'music',
#   'great',
#   'headphon',
#   'rang',
#   'suck',
#   'star',
#   'great',
#   'product',
#   'especi',
#   'price',
#   'good',
#   'workout',
#   'good',
#   'altern',
#   'tone',
#   'best',
#   'bud',
#   'sound',
#   'great',
#   'comfort',
#   'know',
#   'wear',
#   'nice',
#   'qualiti',
#   'style',
#   'bluetooth',
#   'better',
#   'price',
#   'rang',
#   'star',
#   'best',
#   'bang',
#   'buck',
#   'great',
#   'bud',
#   'price',
#   'headset',
#   'wait',
#   'support',
#   'codec',
#   'high',
#   'recommend',
#   'samsung',
#   'owner',
#   'nice',
#   'headphon',
#   'beer',
#   'one',
#   'want',
#   'spend',
#   'littl',
#   'better',
#   'pair',
#   'sound',
#   'high',
#   'volum',
#   'incred',
#   'cheap',
#   'feel',
#   'materi',
#   'easi',
#   'sound',
#   'expect',
#   'interfer',
#   'care',
#   'sound',
#   'qualiti',
#   'good',
#   'neck',
#   'star',
#   'hear',
#   'miss',
#   'bud',
#   'comfort',
#   'wear',
#   'rockin',
#   'work',
#   'iphon',
#   'father',
#   'star',
#   'pretti',
#   'good',
#   'motorcycl',
#   'disappoint',
#   'best',
#   'bluetooth',
#   'headset',
#   'market',
#   'sound',
#   'great',
#   'pretti',
#   'good',
#   'batteri',
#   'life',
#   'star',
#   'work',
#   'great',
#   'bother',
#   'qualiti',
#   'problem',
#   'good',
#   'rang',
#   'connect',
#   'great',
#   'price',
#   'work',
#   'good',
#   'skinni',
#   'neck',
#   'peopl',
#   'match',
#   'tone',
#   'seri',
#   'bluetooth',
#   'headset',
#   'best',
#   'head',
#   'phone',
#   'choke',
#   'great',
#   'headset',
#   'pricepoint',
#   'love',
#   'great',
#   'design',
#   'star',
#   'star',
#   'best',
#   'love',
#   'prittttttti',
#   'prittttttttti',
#   'good',
#   'nice',
#   'motorola',
#   'need',
#   'sell',
#   'replac',
#   'cushion',
#   'nice',
#   'imperfect',
#   'sound',
#   'excel',
#   'mayb',
#   'best',
#   'avail',
#   'bargain',
#   'star',
#   'quiet',
#   'tight',
#   'usual',
#   'rat',
#   'star',
#   'wife',
#   'buy',
#   'christma',
#   'like',
#   'anoth',
#   'like',
#   'better',
#   'tone',
#   'better',
#   'price',
#   'star',
#   'buy',
#   'husband',
#   'super',
#   'excit',
#   'star',
#   'thing',
#   'amaz',
#   'love',
#   'cool',
#   'great',
#   'audio',
#   'comfort',
#   'wear',
#   'sleep',
#   'okay',
#   'easi',
#   'wear',
#   'sound',
#   'qualiti',
#   'great',
#   'minor',
#   'issu',
#   'build',
#   'qualiti',
#   'honest',
#   'review',
#   'terribl',
#   'design',
#   'good',
#   'headphon',
#   'sound',
#   'bass',
#   'improv',
#   'great',
#   'read',
#   'great',
#   'wait',
#   'bose',
#   'make',
#   'form',
#   'factor',
#   'best',
#   'phone',
#   'headset',
#   'headset',
#   'pair',
#   'easili',
#   'surpris',
#   'good',
#   'sound',
#   'qualiti',
#   'price',
#   'buy',
#   'bud',
#   'better',
#   'tone',
#   'better',
#   'nice',
#   'price',
#   'point',
#   'great',
#   'bud',
#   'tini',
#   'neck',
#   'great',
#   'sound',
#   'rang',
#   'like',
#   'happi',
#   'awesom',
#   'good',
#   'excel',
#   'fantast',
#   'comfort',
#   'function',
#   'headphon',
#   'microphon',
#   'call',
#   'perfect',
#   'star',
#   'work',
#   'great',
#   'better',
#   'great',
#   'headphon',
#   'star',
#   'best',
#   'bluetooth',
#   'earbud',
#   'motor',
#   'junka',
#   'great',
#   'sound',
#   'pair',
#   'seamless',
#   'order',
#   'black',
#   'wipe',
#   'daili',
#   'star',
#   'great',
#   'stereo',
#   'headset',
#   'high',
#   'recommend',
#   'awesom',
#   'good',
#   'sound',
#   'sturdi',
#   'feel',
#   'comfort',
#   'great',
#   'sound',
#   'qualiti',
#   'solid',
#   'build',
#   'headphon',
#   'minor',
#   'design',
#   'flaw',
#   'motorola',
#   'bud',
#   'great',
#   'volum',
#   'stick',
#   'star',
#   'poor',
#   'microphon',
#   'qualiti',
#   'star',
#   'smaller',
#   'teach',
#   'rapid',
#   'switch',
#   'like',
#   'press',
#   'hold',
#   'button'],
#  ['comfort',
#   'style',
#   'work',
#   'month',
#   'batteri',
#   'go',
#   'unit',
#   'stock',
#   'explain',
#   'batteri',
#   'failur',
#   'plantron',
#   'send',
#   'work',
#   'year',
#   'batteri',
#   'life',
#   'degrad',
#   'buy',
#   'newer',
#   'style',
#   'similar',
#   'wear',
#   'work',
#   'great',
#   'plantron',
#   'excel',
#   'loud',
#   'speaker',
#   'microphon',
#   'uncomfort',
#   'good',
#   'headset',
#   'great',
#   'custom',
#   'servic'],
#  ['cute',
#   'littl',
#   'clamshel',
#   'phone',
#   'open',
#   'small',
#   'color',
#   'screen',
#   'tradit',
#   'keypad',
#   'blue',
#   'light',
#   'featur',
#   'includ',
#   'speaker',
#   'phone',
#   'great',
#   'headphon',
#   'attach',
#   'camera',
#   'voic',
#   'activ',
#   'dial',
#   'intern',
#   'capabl',
#   'brows',
#   'alarm',
#   'date',
#   'book',
#   'calcul',
#   'standard',
#   'caller',
#   'address',
#   'book',
#   'inform',
#   'camera',
#   'slow',
#   'expect',
#   'catch',
#   'motion',
#   'adequ',
#   'worst',
#   'featur',
#   'ring',
#   'tone',
#   'come',
#   'compar',
#   'nokia',
#   'volum',
#   'high',
#   'hear',
#   'phone',
#   'purs',
#   'want',
#   'distinct',
#   'ring',
#   'tone',
#   'download',
#   'tone',
#   'servic',
#   'provid',
#   'phone',
#   'mini',
#   'connector',
#   'port',
#   'download',
#   'music',
#   'tone',
#   'upload',
#   'pictur',
#   'need',
#   'driver',
#   'work',
#   'expect',
#   'help',
#   'motorola',
#   'site',
#   'useless',
#   'servic',
#   'provid',
#   'salespeopl',
#   'clue',
#   'need',
#   'manual',
#   'come',
#   'phone',
#   'bare',
#   'help',
#   'show',
#   'stroke',
#   'access',
#   'featur',
#   'explain',
#   'crucial',
#   'inform',
#   'exampl',
#   'tell',
#   'access',
#   'melodi',
#   'tell',
#   'actual',
#   'accomplish',
#   'download',
#   'general',
#   'manual',
#   'look',
#   'help',
#   'actual',
#   'write',
#   'review',
#   'phone',
#   'electron',
#   'accessori',
#   'compani',
#   'come',
#   'brand',
#   'auto',
#   'charger',
#   'headset',
#   'servic',
#   'provid',
#   'rat',
#   'want',
#   'plus',
#   'flip',
#   'phone',
#   'style',
#   'make',
#   'small',
#   'palm',
#   'sound',
#   'good',
#   'intern',
#   'capabl',
#   'check',
#   'plan',
#   'versatil',
#   'competitor',
#   'love',
#   'creat',
#   'wallpap',
#   'screensav',
#   'intuit',
#   'stroke',
#   'eventu',
#   'sound',
#   'featur',
#   'motomix',
#   'person',
#   'ring',
#   'tone',
#   'great',
#   'long',
#   'driver',
#   'relat',
#   'camera',
#   'phone',
#   'perform',
#   'surpris',
#   'good',
#   'despit',
#   'nonexist',
#   'support',
#   'phone',
#   'heavili',
#   'discount',
#   'free',
#   'sign',
#   'contract',
#   'worth',
#   'consid',
#   'good',
#   'phone',
#   'decent',
#   'featur',
#   'lousi',
#   'support',
#   'lousi',
#   'root',
#   'current',
#   'cyanogen'],
#  ['previous',
#   'own',
#   'definit',
#   'glad',
#   'switch',
#   'nicest',
#   'reliabl',
#   'phone',
#   'complaint',
#   'verizon',
#   'phone',
#   'antenna',
#   'size',
#   'great',
#   'phone',
#   'flaw',
#   'good',
#   'recept',
#   'decent',
#   'phone',
#   'lose',
#   'cusp',
#   'advanc',
#   'technolog',
#   'good',
#   'phone'],
#  ['like',
#   'contract',
#   'star',
#   'worst',
#   'compani',
#   'good',
#   'star',
#   'absolut',
#   'best'],
#  ['buy',
#   'antenna',
#   'booster',
#   'expect',
#   'cubicl',
#   'reason',
#   'recept',
#   'weak',
#   'phone',
#   'nokia',
#   'crappiest',
#   'antenna',
#   'time',
#   'zero',
#   'bar',
#   'indic',
#   'usual',
#   'bar',
#   'thing',
#   'booster',
#   'haven',
#   'zero',
#   'bar',
#   'time',
#   'averag',
#   'bar',
#   'signal',
#   'margin',
#   'improv',
#   'zero',
#   'accept',
#   'improv',
#   'work',
#   'albeit',
#   'margin',
#   'perfect',
#   'littl',
#   'help',
#   'weak',
#   'area',
#   'absolut',
#   'help',
#   'boost',
#   'recept'],
#  ['work',
#   'pretti',
#   'good',
#   'live',
#   'countri',
#   'hard',
#   'tower',
#   'mile',
#   'away',
#   'alot',
#   'terrain',
#   'abl',
#   'phone',
#   'place',
#   'recommend',
#   'talk',
#   'enought',
#   'signal',
#   'text',
#   'good',
#   'awsom',
#   'love',
#   'star',
#   'star',
#   'work',
#   'star',
#   'star',
#   'star',
#   'star',
#   'signal',
#   'boost',
#   'sure',
#   'star',
#   'star',
#   'actual',
#   'signal',
#   'wors',
#   'good',
#   'thing',
#   'inexpens',
#   'crapwar',
#   'star',
#   'crap',
#   'star',
#   'fool',
#   'good',
#   'useless',
#   'star',
#   'work',
#   'work',
#   'star',
#   'awesom',
#   'suck',
#   'star',
#   'star',
#   'star',
#   'power',
#   'littl',
#   'punch',
#   'joke',
#   'product'],
#  ['read',
#   'pollut',
#   'decid',
#   'meter',
#   'cheap',
#   'discov',
#   'danger',
#   'level',
#   'leak',
#   'radiat',
#   'year',
#   'microwav',
#   'oven',
#   'probabl',
#   'replac',
#   'oven',
#   'stand',
#   'awar',
#   'smart',
#   'high',
#   'qualiti',
#   'meter',
#   'think',
#   'easi',
#   'great',
#   'locat',
#   'magnet',
#   'wave',
#   'eman',
#   'larg',
#   'electr',
#   'motor',
#   'danger',
#   'wave',
#   'consist',
#   'retro',
#   'meter',
#   'unknown',
#   'accuraci',
#   'good',
#   'product',
#   'star',
#   'neat',
#   'gadget',
#   'discov',
#   'stray',
#   'electron',
#   'signal',
#   'strength',
#   'recommend',
#   'star',
#   'handi',
#   'magnet',
#   'field',
#   'that',
#   'close',
#   'get',
#   'good',
#   'star',
#   'good',
#   'devic',
#   'look',
#   'deliveri',
#   'great',
#   'shock',
#   'go',
#   'find',
#   'electromagnet',
#   'interfer',
#   'star',
#   'work',
#   'great',
#   'great',
#   'product',
#   'show',
#   'power',
#   'line',
#   'energi',
#   'milligauss',
#   'total',
#   'worth',
#   'money',
#   'star',
#   'star',
#   'afraid',
#   'ghost',
#   'watch',
#   'microwav',
#   'radiat',
#   'scari',
#   'good',
#   'help',
#   'good',
#   'valu',
#   'electron',
#   'devic',
#   'home',
#   'feel',
#   'better',
#   'get',
#   'idea',
#   'devic',
#   'area',
#   'trifield',
#   'meter',
#   'star'],
#  ['thank', 'star', 'total', 'junk', 'fight', 'tweak', 'real', 'deal', 'excel'],
#  ['sidekick',
#   'better',
#   'form',
#   'factor',
#   'competitor',
#   'treo',
#   'blackberri',
#   'offer',
#   'better',
#   'comfort',
#   'keyboard',
#   'like',
#   'mini',
#   'phone',
#   'like',
#   'fulli',
#   'multitask',
#   'unlik',
#   'palm',
#   'download',
#   'webpag',
#   'check',
#   'email',
#   'chat',
#   'time',
#   'unlik',
#   'palm',
#   'interrupt',
#   'process',
#   'leav',
#   'applic',
#   'sidekick',
#   'yahoo',
#   'messeng',
#   'like',
#   'build',
#   'camera',
#   'miss',
#   'have',
#   'palm',
#   'especi',
#   'intellisync',
#   'sidekick',
#   'sync',
#   'contact',
#   'calendar',
#   'inform',
#   'desktop',
#   'like',
#   'stylus',
#   'input',
#   'palm',
#   'keyboard',
#   'sidekick',
#   'better',
#   'blackberri',
#   'unit',
#   'nice',
#   'sidekick',
#   'cool',
#   'easier',
#   'better',
#   'instant',
#   'messag',
#   'capabl',
#   'slight',
#   'complaint',
#   'sidekick',
#   'replacebl',
#   'batteri',
#   'prefer',
#   'abl',
#   'swap',
#   'batteri',
#   'better',
#   'altern',
#   'awkward',
#   'unreli',
#   'sidekick',
#   'best',
#   'friend',
#   'poor',
#   'recption',
#   'poor',
#   'tech',
#   'support',
#   'okay',
#   'star',
#   'sidekick',
#   'best',
#   'phone',
#   'own',
#   'better',
#   'devic',
#   'blackberri',
#   'treo',
#   'need'],
#  ['wood',
#   'nice',
#   'smooth',
#   'like',
#   'basketbal',
#   'court',
#   'bowl',
#   'lane',
#   'fit',
#   'iphon',
#   'fine',
#   'offer',
#   'screen',
#   'protect',
#   'side',
#   'lower',
#   'sure',
#   'good',
#   'screen',
#   'protector',
#   'wood',
#   'panel',
#   'classi',
#   'choic',
#   'case',
#   'high',
#   'recommend',
#   'beauti',
#   'case',
#   'love',
#   'case',
#   'worth',
#   'beauti',
#   'case',
#   'great',
#   'case',
#   'look',
#   'uniqu',
#   'case',
#   'price',
#   'wood',
#   'panel',
#   'classi',
#   'choic',
#   'case',
#   'great',
#   'product'],
#  ['nice',
#   'phone',
#   'year',
#   'think',
#   'nicer',
#   'screen',
#   'screen',
#   'qualiti',
#   'small',
#   'upgrad',
#   'biggest',
#   'warn',
#   'return',
#   'seller',
#   'true',
#   'nightmar',
#   'read',
#   'fine',
#   'print',
#   'seller',
#   'cingular',
#   'immedi',
#   'separ',
#   'sure',
#   'sure',
#   'track',
#   'number',
#   'return',
#   'packag',
#   'link',
#   'seller',
#   'cingular',
#   'seller',
#   'respons',
#   'plan',
#   'track',
#   'number',
#   'think',
#   'phone',
#   'phone',
#   'activ',
#   'second',
#   'ship',
#   'pay',
#   'charg',
#   'time',
#   'turn',
#   'phone',
#   'talk',
#   'second',
#   'phone',
#   'pay',
#   'week',
#   'shipment',
#   'time',
#   'like',
#   'phone',
#   'turn',
#   'cingular',
#   'know',
#   'seller',
#   'resel',
#   'seller',
#   'know',
#   'cingular',
#   'cingular',
#   'tracker',
#   'packag',
#   'return',
#   'prove',
#   'need',
#   'print',
#   'return',
#   'page',
#   'cingular',
#   'prove',
#   'return',
#   'take',
#   'hour',
#   'half',
#   'lucki',
#   'like',
#   'take',
#   'care',
#   'bewar',
#   'return',
#   'bluetooth',
#   'batteri',
#   'life',
#   'slow',
#   'processor',
#   'bug',
#   'great',
#   'devic'],
#  ['buy',
#   'say',
#   'okay',
#   'okay',
#   'listen',
#   'music',
#   'couldn',
#   'cell',
#   'phone',
#   'intend',
#   'headset',
#   'motorola',
#   'mono',
#   'hand',
#   'free',
#   'headset',
#   'black',
#   'star',
#   'sturdi',
#   'good',
#   'product',
#   'star',
#   'star',
#   'ident',
#   'replac',
#   'motorola',
#   'hand',
#   'free',
#   'headset',
#   'real',
#   'motorola',
#   'deal',
#   'great',
#   'price',
#   'work',
#   'work',
#   'perfect',
#   'work',
#   'great',
#   'star',
#   'great',
#   'product',
#   'high',
#   'recommend',
#   'work',
#   'radio'],
#  ['treo',
#   'month',
#   'agre',
#   'rater',
#   'problem',
#   'reset',
#   'spontan',
#   'usabl',
#   'memori',
#   'phone',
#   'qualiti',
#   'good',
#   'palmon',
#   'updat',
#   'fix',
#   'problem',
#   'usabl',
#   'memori',
#   'go',
#   'phone',
#   'complet',
#   'stabl',
#   'need',
#   'reserv',
#   'anymor',
#   'updat',
#   'avail',
#   'cingular',
#   'suppos',
#   'eventu',
#   'palmon',
#   'updat',
#   'fix',
#   'flaw'],
#  ['older',
#   'port',
#   'laptop',
#   'port',
#   'extern',
#   'drive',
#   'printer',
#   'devic',
# ...
#   'outstand',
#   'perform',
#   'return'],
#  ['tuneband',
#   'open',
#   'simpl',
#   'design',
#   'access',
#   'app',
#   'volum',
#   'control',
#   'earphon',
#   'jack',
#   'iphon',
#   'fit',
#   'easili',
#   'soft',
#   'shell',
#   'wide',
#   'armband',
#   'long',
#   'wrist',
#   'wear',
#   'slip',
#   'free',
#   'upper',
#   'activ',
#   'housework',
#   'session',
#   'current',
#   'skullcandi',
#   'headphon',
#   'open',
#   'access',
#   'attach',
#   'item',
#   'bulki',
#   'wear',
#   'sleev',
#   'public',
#   'place',
#   'tuneband',
#   'iphon',
#   'best',
#   'world',
#   'great',
#   'iphon',
#   'band'],
#  ['good',
#   'star',
#   'star',
#   'pretti',
#   'good',
#   'motorola',
#   'bluetooth',
#   'work',
#   'motorola',
#   'blur',
#   'tooth',
#   'headset'],
#  ['test',
#   'iphon',
#   'older',
#   'motorola',
#   'flip',
#   'phone',
#   'pair',
#   'easili',
#   'sound',
#   'qualiti',
#   'great',
#   'haven',
#   'hear',
#   'complaint',
#   'devic',
#   'power',
#   'quick',
#   'forget',
#   'turn',
#   'start',
#   'drive',
#   'connect',
#   'fast',
#   'drop',
#   'voicemail',
#   'simpl',
#   'design',
#   'simpl',
#   'love',
#   'port',
#   'basic',
#   'charg',
#   'greatest',
#   'challeng',
#   'get',
#   'suction',
#   'cup',
#   'stick',
#   'windshield',
#   'perform',
#   'product',
#   'function',
#   'clean',
#   'spot',
#   'want',
#   'mount',
#   'unit',
#   'actual',
#   'holster',
#   'remov',
#   'drive',
#   'convers',
#   'love',
#   'buy',
#   'multipl',
#   'think',
#   'disappoint',
#   'pair',
#   'easili',
#   'sound',
#   'qualiti',
#   'great',
#   'echo',
#   'hear',
#   'time',
#   'recommend',
#   'blue',
#   'toot',
#   'build',
#   'cheapli',
#   'love',
#   'samsung',
#   'phone'],
#  ['love',
#   'blackberri',
#   'haven',
#   'love',
#   'model',
#   'differ',
#   'great',
#   'phone',
#   'nice',
#   'featur',
#   'easi',
#   'pretti',
#   'buy',
#   'good',
#   'condit',
#   'phone',
#   'teczilla',
#   'gorgeous',
#   'condit',
#   'cost',
#   'brand',
#   'arriv',
#   'day',
#   'earli',
#   'veryyi',
#   'happi',
#   'purchas',
#   'phone',
#   'give',
#   'blackberri',
#   'curv',
#   'star',
#   'revis',
#   'review',
#   'chang',
#   'review',
#   'phone',
#   'rare',
#   'send',
#   'pictur',
#   'take',
#   'receiv',
#   'caus',
#   'appear',
#   'complet',
#   'imposs',
#   'view',
#   'partial',
#   'viewabl',
#   'newer',
#   'phone',
#   'work',
#   'fine',
#   'think',
#   'older',
#   'version',
#   'phone',
#   'disappoint',
#   'previous',
#   'phone',
#   'camera',
#   'purchas',
#   'reflect',
#   'seller',
#   'futur',
#   'purchas',
#   'older',
#   'model',
#   'phone',
#   'good',
#   'revis',
#   'review',
#   'blackberri',
#   'servic',
#   'messeng',
#   'work',
#   'dont',
#   'vibecellular',
#   'great',
#   'crappi',
#   'phone',
#   'star',
#   'star',
#   'unexpect',
#   'phone',
#   'arriv',
#   'work',
#   'star',
#   'nice',
#   'phone',
#   'return',
#   'item',
#   'blackberri',
#   'cell',
#   'phone',
#   'excel',
#   'product',
#   'recommend',
#   'star'],
#  ['excelent', 'star', 'star', 'nice'],
#  ['thank',
#   'star',
#   'price',
#   'ayuda',
#   'bater',
#   'iacut',
#   'extra',
#   'pero',
#   'carga',
#   'bater',
#   'iacut',
#   'help',
#   'extra',
#   'batteri',
#   'charg',
#   'happi',
#   'star'],
#  ['good', 'product', 'star', 'star', 'perfect'],
#  ['love', 'star', 'great', 'product', 'excel'],
#  ['work',
#   'need',
#   'retract',
#   'easili',
#   'allow',
#   'charg',
#   'drive',
#   'great',
#   'price',
#   'definet',
#   'worth',
#   'function',
#   'great',
#   'good',
#   'deal'],
#  ['good', 'star', 'star', 'poor', 'design', 'touchscreen'],
#  ['truli',
#   'amaz',
#   'fastest',
#   'solar',
#   'batteri',
#   'charger',
#   'own',
#   'charg',
#   'indic',
#   'light',
#   'batteri',
#   'compart',
#   'charg',
#   'batteri',
#   'time',
#   'know',
#   'charg',
#   'status',
#   'pair',
#   'connector',
#   'model',
#   'combin',
#   'item',
#   'nbsp',
#   'data',
#   'hook',
#   'product',
#   'link',
#   'link',
#   'class',
#   'link',
#   'normal',
#   'href',
#   'tekkeon',
#   'tekcharg',
#   'mobil',
#   'power',
#   'batteri',
#   'charger',
#   'tekkeon',
#   'tekcharg',
#   'mobil',
#   'power',
#   'batteri',
#   'charger',
#   'charg',
#   'powerfilm',
#   'make',
#   'batteri',
#   'version',
#   'product',
#   'power',
#   'charg',
#   'generat',
#   'ipod',
#   'touch',
#   'batteri',
#   'version',
#   'solar',
#   'panel',
#   'oppos',
#   'unit',
#   'charg',
#   'pretti',
#   'straightforward',
#   'indic',
#   'light',
#   'state',
#   'fast',
#   'faint',
#   'blink',
#   'show',
#   'sunlight',
#   'avail',
#   'strong',
#   'activ',
#   'charg',
#   'circuit',
#   'steadi',
#   'second',
#   'blink',
#   'show',
#   'batteri',
#   'section',
#   'charg',
#   'light',
#   'abl',
#   'activ',
#   'charger',
#   'watt',
#   'light',
#   'bulb',
#   'cours',
#   'sunlight',
#   'work',
#   'faster',
#   'steadi',
#   'light',
#   'show',
#   'batteri',
#   'charg',
#   'bright',
#   'daylight',
#   'abl',
#   'charg',
#   'signific',
#   'drain',
#   'batteri',
#   'hour',
#   'complet',
#   'dead',
#   'batteri',
#   'hour',
#   'combin',
#   'item',
#   'tekcharg',
#   'extra',
#   'batteri',
#   'abl',
#   'ipod',
#   'cell',
#   'phone',
#   'grid',
#   'complet',
#   'excel',
#   'charger'],
#  ['product',
#   'suppos',
#   'charg',
#   'phone',
#   'fast',
#   'act',
#   'post',
#   'want',
#   'price',
#   'charg',
#   'transfer',
#   'cell',
#   'vesa',
#   'versa',
#   'think',
#   'greatest',
#   'negat',
#   'charg',
#   'phone',
#   'quick',
#   'good',
#   'product',
#   'break',
#   'work',
#   'great',
#   'star',
#   'star',
#   'star',
#   'genuin',
#   'charger',
#   'good',
#   'stuff',
#   'cheap',
#   'price',
#   'come',
#   'easili',
#   'tini',
#   'touch',
#   'disconnect',
#   'phone',
#   'great',
#   'charger',
#   'cell',
#   'phone',
#   'charger',
#   'great',
#   'deal',
#   'work',
#   'worth',
#   'money',
#   'refund',
#   'work',
#   'incit',
#   'great',
#   'littl',
#   'charger',
#   'charger',
#   'work',
#   'great',
#   'month',
#   'later',
#   'work',
#   'like',
#   'charm',
#   'love',
#   'home',
#   'charger',
#   'data',
#   'cabl',
#   'possibl',
#   'refurbish',
#   'great',
#   'good',
#   'cheap',
#   'great',
#   'product',
#   'arriv',
#   'quick',
#   'star',
#   'work',
#   'expect',
#   'excel',
#   'charger',
#   'solid',
#   'high',
#   'qualiti',
#   'star',
#   'univers',
#   'android',
#   'charger',
#   'hold',
#   'cord',
#   'stiff',
#   'great',
#   'charger',
#   'work',
#   'nexus',
#   'fantast',
#   'littl',
#   'charger',
#   'work',
#   'good',
#   'work',
#   'good',
#   'home',
#   'charger',
#   'perfect',
#   'replac',
#   'charger',
#   'junk',
#   'wast',
#   'time',
#   'origin',
#   'work',
#   'like',
#   'champ',
#   'great',
#   'custom',
#   'servic',
#   'star',
#   'charger',
#   'real',
#   'deal',
#   'pass',
#   'charger',
#   'star',
#   'actual',
#   'work',
#   'optimus',
#   'star',
#   'cord',
#   'charger'],
#  ['thing',
#   'smell',
#   'couldn',
#   'week',
#   'toler',
#   'notic',
#   'glue',
#   'hold',
#   'rubber',
#   'base',
#   'melt',
#   'rubber',
#   'strip',
#   'shift',
#   'place',
#   'hair',
#   'dust',
#   'cling',
#   'expos',
#   'glue',
#   'deal',
#   'breaker',
#   'laptop',
#   'cool',
#   'gross',
#   'perform',
#   'reason',
#   'better',
#   'laptop',
#   'case',
#   'littl',
#   'tab',
#   'prop',
#   'laptop',
#   'better',
#   'ventil',
#   'review',
#   'post',
#   'recent',
#   'review',
#   'criteria',
#   'boil',
#   'wreck',
#   'stink',
#   'factor',
#   'terribl',
#   'product',
#   'slim',
#   'stinki',
#   'wife',
#   'purchas',
#   'star',
#   'great',
#   'laptop',
#   'desk',
#   'nice',
#   'slip',
#   'surfac',
#   'mackbook',
#   'scrath',
#   'surfac',
#   'star',
#   'star',
#   'star',
#   'smell',
#   'away',
#   'best',
#   'laptop',
#   'cooler',
#   'worth',
#   'money',
#   'laptop',
#   'cooler',
#   'perfect',
#   'laptop',
#   'crack',
#   'break',
#   'month',
#   'good',
#   'product',
#   'liter',
#   'smell',
#   'laptop',
#   'cool',
#   'look',
#   'littl',
#   'weird',
#   'work',
#   'work',
#   'great',
#   'smell',
#   'rubber',
#   'unglu',
#   'plastic',
#   'xpad',
#   'slim',
#   'disapoint',
#   'good',
#   'carri',
#   'work',
#   'great',
#   'work',
#   'work',
#   'like',
#   'xpad',
#   'slim',
#   'good',
#   'idea',
#   'flaw',
#   'laptop',
#   'cooler',
#   'heatshield',
#   'revers',
#   'know',
#   'cool',
#   'want',
#   'noisi',
#   'fan',
#   'drain',
#   'say'],
#  ['run',
#   'parti',
#   'cyanogenmod',
#   'cupcak',
#   'plus',
#   'donut',
#   'dream',
#   'work',
#   'tri',
#   'port',
#   'headset',
#   'port',
#   'charg',
#   'good',
#   'headset',
#   'switch',
#   'softwar',
#   'thing',
#   'simpl',
#   'adapt',
#   'mobil',
#   'need',
#   'dedic',
#   'purpos',
#   'good',
#   'stationari',
#   'want',
#   'charg',
#   'listen',
#   'headset',
#   'time',
#   'work',
#   'cupcak',
#   'minor',
#   'hitch',
#   'phone',
#   'charg',
#   'listen',
#   'heawdphon',
#   'time',
#   'star',
#   'garbag',
#   'need',
#   'love'],
#  ['receiev',
#   'phone',
#   'happi',
#   'know',
#   'actual',
#   'unlock',
#   'work',
#   'avail',
#   'network',
#   'phone',
#   'wonder',
#   'lose',
#   'star',
#   'softwar',
#   'phone',
#   'sell',
#   'softwar',
#   'leav',
#   'search',
#   'internet',
#   'download',
#   'softwar',
#   'holster',
#   'come',
#   'phone',
#   'origin',
#   'version',
#   'imit',
#   'china',
#   'origin',
#   'deal',
#   'phone',
#   'automat',
#   'lock',
#   'revert',
#   'sleep',
#   'mode',
#   'place',
#   'holder',
#   'place',
#   'phone',
#   'brother',
#   'holster',
#   'phone',
#   'revert',
#   'lock',
#   'mode',
#   'expect',
#   'rememb',
#   'effort',
#   'consum',
#   'money',
#   'item',
#   'effort',
#   'seller',
#   'ensur',
#   'item',
#   'packag',
#   'perfect',
#   'wari',
#   'folk',
#   'blackberri',
#   'screen',
#   'protect',
#   'blackberri',
#   'curv',
#   'screen',
#   'protector',
#   'good',
#   'product',
#   'price'],
#  ['work',
#   'great',
#   'tracfon',
#   'star',
#   'small',
#   'phone',
#   'easi',
#   'form',
#   'hotspot',
#   'freedompop',
#   'samsung',
#   'great',
#   'item',
#   'wrong',
#   'size',
#   'worth',
#   'invest',
#   'love',
#   'compani'],
#  ['excel',
#   'choic',
#   'look',
#   'touch',
#   'screen',
#   'smart',
#   'phone',
#   'phew',
#   'touch',
#   'screen',
#   'phone',
#   'past',
#   'best',
#   'thing',
#   'wasn',
#   'happi',
#   'camera',
#   'good',
#   'light',
#   'rest',
#   'fantast',
#   'differ',
#   'write',
#   'mode',
#   'best',
#   'notic',
#   'touch',
#   'screen',
#   'berceus',
#   'blast',
#   'email',
#   'messag',
#   'like',
#   'keyboard',
#   'cell',
#   'phone',
#   'definit',
#   'iphon',
#   'killer',
#   'love',
#   'nice',
#   'phone',
#   'break',
#   'month',
#   'good',
#   'devic',
#   'star',
#   'half',
#   'mayb',
#   'star',
#   'good',
#   'great',
#   'amaz',
#   'phone',
#   'price',
#   'rang',
#   'solid',
#   'real',
#   'world',
#   'owner',
#   'good',
#   'phone',
#   'review',
#   'month',
#   'usag',
#   'memori',
#   'messag',
#   'unicod',
#   'support',
#   'best',
#   'phone',
#   'market',
#   'generat',
#   'nokia',
#   'rememb',
#   'move',
#   'includ',
#   'nokia',
#   'star',
#   'simpli',
#   'best',
#   'phone',
#   'good',
#   'phone',
#   'nokia',
#   'xpressmus',
#   'unlock',
#   'phone',
#   'star',
#   'best',
#   'nokia',
#   'wait',
#   'best',
#   'phone',
#   'go',
#   'good',
#   'slvr',
#   'pleasant',
#   'surpris',
#   'impress',
#   'price',
#   'good',
#   'product',
#   'great',
#   'phone',
#   'nokia',
#   'smartphon',
#   'work',
#   'good',
#   'perfect',
#   'phone',
#   'freez',
#   'problem',
#   'suggest',
#   'nokia',
#   'instead',
#   'readon',
#   'love',
#   'phone',
#   'thou',
#   'nokia',
#   'nokia',
#   'music'],
#  ['admit',
#   'phone',
#   'inferior',
#   'smart',
#   'phone',
#   'current',
#   'market',
#   'requir',
#   'data',
#   'plan',
#   'like',
#   'want',
#   'qualiti',
#   'phone',
#   'have',
#   'data',
#   'plan',
#   'phone',
#   'blackberri',
#   'pearl',
#   'year',
#   'pretti',
#   'familiar',
#   'pros',
#   'con',
#   'pros',
#   'modifi',
#   'qwerti',
#   'keyboard',
#   'qwerti',
#   'button',
#   'share',
#   'letter',
#   'common',
#   'huge',
#   'improv',
#   'smart',
#   'phone',
#   'qualiti',
#   'calendar',
#   'good',
#   'media',
#   'player',
#   'bluetooth',
#   'great',
#   'address',
#   'book',
#   'option',
#   'unlimit',
#   'text',
#   'inbox',
#   'space',
#   'text',
#   'limit',
#   'virtual',
#   'phone',
#   'text',
#   'search',
#   'option',
#   'great',
#   'look',
#   'text',
#   'need',
#   'rememb',
#   'send',
#   'voic',
#   'dial',
#   'fit',
#   'pocket',
#   'size',
#   'file',
#   'rington',
#   'alarm',
#   'con',
#   'camera',
#   'video',
#   'camera',
#   'good',
#   'understand',
#   'peopl',
#   'phone',
#   'camera',
#   'import',
#   'calendar',
#   'address',
#   'book',
#   'wifi',
#   'phone',
#   'like',
#   'roller',
#   'ball',
#   'mous',
#   'year',
#   'track',
#   'ball',
#   'need',
#   'clean',
#   'tutori',
#   'onlin',
#   'explain',
#   'clean',
#   'work',
#   'like',
#   'headphon',
#   'jack',
#   'smaller',
#   'standard',
#   'headphon',
#   'want',
#   'standard',
#   'jack',
#   'probabl',
#   'want',
#   'upgrad',
#   'pearl',
#   'phone',
#   'away',
#   'best',
#   'smart',
#   'phone',
#   'best',
#   'smart',
#   'phone',
#   'star',
#   'star',
#   'good',
#   'star'],
#  ['star',
#   'look',
#   'like',
#   'blackberri',
#   'headphon',
#   'decent',
#   'sound',
#   'comfort',
#   'great'],
#  ['tracfon',
#   'year',
#   'initi',
#   'write',
#   'harsh',
#   'review',
#   'add',
#   'minut',
#   'phone',
#   'websit',
#   'nightmar',
#   'chang',
#   'add',
#   'minut',
#   'couldn',
#   'easier',
#   'add',
#   'line',
#   'number',
#   'basic',
#   'enter',
#   'serial',
#   'number',
#   'click',
#   'continu',
#   'recent',
#   'upgrad',
#   'phone',
#   'model',
#   'transfer',
#   'telephon',
#   'number',
#   'older',
#   'phone',
#   'easili',
#   'websit',
#   'model',
#   'better',
#   'older',
#   'phone',
#   'volum',
#   'sound',
#   'qualiti',
#   'great',
#   'flip',
#   'case',
#   'doubl',
#   'minut',
#   'featur',
#   'great',
#   'tracfon',
#   'nice',
#   'thing',
#   'like',
#   'free',
#   'minut',
#   'birthday',
#   'pleas',
#   'phone',
#   'servic',
#   'tracfon',
#   'servic',
#   'improv',
#   'tremend',
#   'bother',
#   'upgrad',
#   'tracfon',
#   'help',
#   'useless'],
#  ['good',
#   'hardwar',
#   'solid',
#   'build',
#   'phone',
#   'nice',
#   'display',
#   'good',
#   'keyboard',
#   'flip',
#   'open',
#   'mechan',
#   'durabl',
#   'daili',
#   'provid',
#   'habit',
#   'pop',
#   'open',
#   'like',
#   'switchblad',
#   'touch',
#   'screen',
#   'think',
#   'user',
#   'interfac',
#   'problem',
#   'softwar',
#   'fair',
#   'softwar',
#   'actual',
#   'write',
#   'stabl',
#   'lock',
#   'mobil',
#   'mobil',
#   'longer',
#   'support',
#   'phone',
#   'ergo',
#   'game',
#   'stop',
#   'issu',
#   'phone',
#   'period',
#   'attempt',
#   'establish',
#   'data',
#   'connect',
#   'servic',
#   'mobil',
#   'longer',
#   'provid',
#   'caus',
#   'batteri',
#   'pound',
#   'mobil',
#   'data',
#   'plan',
#   'incur',
#   'charg',
#   'persist',
#   'activ',
#   'auto',
#   'lock',
#   'data',
#   'plan',
#   'phone',
#   'stall',
#   'wait',
#   'code',
#   'unabl',
#   'accept',
#   'call',
#   'text',
#   'cycl',
#   'hour',
#   'requir',
#   'unlock',
#   'check',
#   'phone',
#   'status',
#   'featur',
#   'phone',
#   'allow',
#   'configur',
#   'activ',
#   'data',
#   'connect',
#   'wifi',
#   'overal',
#   'nbsp',
#   'data',
#   'hook',
#   'product',
#   'link',
#   'link',
#   'class',
#   'link',
#   'normal',
#   'href',
#   'sidekick',
#   'quadband',
#   'phone',
#   'mobil',
#   'sidekick',
#   'quadband',
#   'phone',
#   'mobil',
#   'nbsp',
#   'good',
#   'phone',
#   'fix',
#   'like',
#   'fix',
#   'nbsp',
#   'data',
#   'hook',
#   'product',
#   'link',
#   'link',
#   'class',
#   'link',
#   'normal',
#   'href',
#   'sidekick',
#   'unlock',
#   'phone',
#   'qwerti',
#   'keyboard',
#   'warranti',
#   'carbon',
#   'gray',
#   'sidekick',
#   'unlock',
#   'phone',
#   'qwerti',
#   'keyboard',
#   'warranti',
#   'carbon',
#   'gray',
#   'nbsp',
#   'stick',
#   'fool',
#   'date',
#   'softwar',
#   'phone',
#   'use',
#   'go',
#   'mess',
#   'sidekick',
#   'phone',
#   'daili',
#   'carri',
#   'good',
#   'hardwar',
#   'softwar',
#   'outdat',
#   'cool',
#   'stop',
#   'work',
#   'day',
#   'later',
#   'expect',
#   'sidekick',
#   'devic',
#   'function',
#   'power',
#   'roger'],
#  ['excel', 'star', 'good', 'thank', 'star'],
#  ['good',
#   'iphon',
#   'good',
#   'star',
#   'love',
#   'star',
#   'star',
#   'buy',
#   'pack',
#   'seller',
#   'take',
#   'approxim',
#   'day',
#   'star',
#   'star',
#   'great',
#   'product',
#   'work',
#   'fine',
#   'screen',
#   'saver',
#   'good',
#   'price',
#   'reason',
#   'qualiti',
#   'star',
#   'star',
#   'star',
#   'star',
#   'good',
#   'protector',
#   'cover',
#   'screen',
#   'excel',
#   'valu',
#   'good',
#   'valu',
#   'good',
#   'work',
#   'star',
#   'littl',
#   'smear',
#   'price',
#   'star',
#   'star',
#   'real',
#   'cheap',
#   'fit',
#   'phone',
#   'perfect',
#   'great',
#   'product',
#   'excel',
#   'product',
#   'star',
#   'good',
#   'qualiti'],
#  ['work',
#   'pretti',
#   'good',
#   'reason',
#   'give',
#   'star',
#   'annoy',
#   'shut',
#   'stay',
#   'drain',
#   'batteri',
#   'great',
#   'transmitt',
#   'get',
#   'fuzzi',
#   'batter',
#   'signal',
#   'cabl',
#   'near',
#   'radio',
#   'work',
#   'pretti',
#   'good',
#   'better',
#   'fight',
#   'cabl',
#   'listen',
#   'music',
#   'phone',
#   'hand',
#   'free',
#   'devic',
#   'think',
#   'suck',
#   'hear',
#   'right',
#   'face',
#   'visor',
#   'cliff',
#   'work',
#   'pretti',
#   'good',
#   'transmitt',
#   'great',
#   'suck',
#   'hand',
#   'free',
#   'work',
#   'pretti',
#   'good',
#   'good',
#   'unit',
#   'money',
#   'wonder',
#   'adequ',
#   'hand',
#   'free',
#   'speaker',
#   'phone',
#   'recommend',
#   'hand',
#   'free',
#   'speakerphon'],
#  ...]

# %%
len(processed_docs)
# Out:
# 48134

# %%
# print some tokenized and preprocessed doc.
print(processed_docs[:2])
# Out:
# [['good', 'case', 'price', 'right', 'problem', 'lose', 'stone', 'purchas', 'rough', 'recommend', 'love', 'case', 'show', 'pretti', 'cute', 'cute', 'bing', 'bling', 'love', 'cute', 'tightt', 'star', 'crystal', 'case', 'cute', 'great', 'gift', 'love', 'invis', 'case', 'ador', 'gonna', 'order', 'rest', 'love', 'case', 'beauti', 'sara', 'stop', 'case', 'bling', 'cute', 'bling', 'bling', 'iphon', 'bling', 'worth', 'great', 'price', 'cute', 'spark', 'good', 'love', 'phone', 'cover', 'pretti', 'cute', 'amaz', 'great', 'cheap', 'plastic', 'okay', 'phone', 'case', 'love', 'great', 'case'], ['excit', 'case', 'love', 'color', 'feel', 'start', 'notic', 'stuff', 'hand', 'realiz', 'rubber', 'peel', 'right', 'phone', 'normal', 'say', 'go', 'wast', 'money', 'cover', 'better', 'expect', 'expect', 'star', 'star', 'love', 'product']]

# %% [markdown]
# #Feature Extraction
#
# **Create Dictionary of tokens with words(values) and keys(Ids)**

# %%
# Making a dictionary cotaining words and their integer ids
dictionary = gensim.corpora.Dictionary(processed_docs)

# %%
print (dictionary)
# Out:
# Dictionary(25210 unique tokens: ['ador', 'amaz', 'beauti', 'bing', 'bling']...)

# %%
#Lets see if dictionary created succesfully
# Printing first 20 items in dictionary
count=0
for k,v in dictionary.iteritems():
    print (k, v)
    count +=1
    if count >20:
        break
# Out:
# 0 ador
# 1 amaz
# 2 beauti
# 3 bing
# 4 bling
# 5 case
# 6 cheap
# 7 cover
# 8 crystal
# 9 cute
# 10 gift
# 11 gonna
# 12 good
# 13 great
# 14 invis
# 15 iphon
# 16 lose
# 17 love
# 18 okay
# 19 order
# 20 phone

# %%
#remove rare and repeatative words
dictionary.filter_extremes()

# %%
print (dictionary)
# Out:
# Dictionary(6672 unique tokens: ['ador', 'amaz', 'beauti', 'bing', 'bling']...)

# %% [markdown]
# **Create Corpus: Term Document Frequency**
#
# apply TFIDF BOW techniques to Doc. term Freq Matrix

# %%
# Applying Bag-of-Words for each document (a list of words)
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

print("Bag-of-Words of our sample document: ", bow_corpus[0])
# Out:
# Bag-of-Words of our sample document:  [(0, 1), (1, 1), (2, 1), (3, 1), (4, 5), (5, 1), (6, 1), (7, 1), (8, 7), (9, 1), (10, 1), (11, 1), (12, 1), (13, 1), (14, 6), (15, 1), (16, 1), (17, 1), (18, 2), (19, 2), (20, 1), (21, 1), (22, 1), (23, 1), (24, 1), (25, 1), (26, 1), (27, 1), (28, 1), (29, 1), (30, 1)]

# %%
#preview for first document
document_num = 0
bow_doc_x = bow_corpus[document_num]

for i in range(len(bow_doc_x)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_x[i][0], 
                                                     dictionary[bow_doc_x[i][0]],
                                                     bow_doc_x[i][1]))
# Out:
# Word 0 ("ador") appears 1 time.
# Word 1 ("amaz") appears 1 time.
# Word 2 ("beauti") appears 1 time.
# Word 3 ("bing") appears 1 time.
# Word 4 ("bling") appears 5 time.
# Word 5 ("cheap") appears 1 time.
# Word 6 ("cover") appears 1 time.
# Word 7 ("crystal") appears 1 time.
# Word 8 ("cute") appears 7 time.
# Word 9 ("gift") appears 1 time.
# Word 10 ("gonna") appears 1 time.
# Word 11 ("invis") appears 1 time.
# Word 12 ("iphon") appears 1 time.
# Word 13 ("lose") appears 1 time.
# Word 14 ("love") appears 6 time.
# Word 15 ("okay") appears 1 time.
# Word 16 ("order") appears 1 time.
# Word 17 ("plastic") appears 1 time.
# Word 18 ("pretti") appears 2 time.
# Word 19 ("price") appears 2 time.
# Word 20 ("problem") appears 1 time.
# Word 21 ("purchas") appears 1 time.
# Word 22 ("recommend") appears 1 time.
# Word 23 ("rest") appears 1 time.
# Word 24 ("right") appears 1 time.
# Word 25 ("rough") appears 1 time.
# Word 26 ("show") appears 1 time.
# Word 27 ("spark") appears 1 time.
# Word 28 ("stone") appears 1 time.
# Word 29 ("stop") appears 1 time.
# Word 30 ("worth") appears 1 time.

# %%
# Importing the libraries
from gensim import corpora, models
from pprint import pprint

# %%
# Creating a TF-IDF model
tfidf = models.TfidfModel(corpus = bow_corpus)

# %%
# Applying TF-IDF to the entire corpus
tfidf_corpus = tfidf[bow_corpus]
print("1st TD-IDF: ", tfidf_corpus[0])
# Out:
# 1st TD-IDF:  [(0, 0.12857693135382176), (1, 0.07088904400818548), (2, 0.07270000919918872), (3, 0.2263143839580936), (4, 0.6380464879110068), (5, 0.060903690895697596), (6, 0.050169938855455946), (7, 0.12105864203693423), (8, 0.49627756753866853), (9, 0.08820290919186652), (10, 0.15883065190689077), (11, 0.14657483933458415), (12, 0.04841519249890269), (13, 0.10137137879666572), (14, 0.147305012465708), (15, 0.0775735862554975), (16, 0.07012493718109294), (17, 0.06920653107503927), (18, 0.10457377484719263), (19, 0.06983204044565798), (20, 0.06851636490289492), (21, 0.05682679653951866), (22, 0.04749072638098378), (23, 0.1281857057842942), (24, 0.06922109885294067), (25, 0.12773632883684785), (26, 0.10047542276581711), (27, 0.16367179739783014), (28, 0.1704902553614631), (29, 0.09929566125618666), (30, 0.06153747314143853)]

# %%
# Preview TF-IDF for first document
count = 0
for doc in tfidf_corpus:
    pprint(doc)
    count += 1
    if count ==2:
        break
# Out:
# [(0, 0.12857693135382176),
#  (1, 0.07088904400818548),
#  (2, 0.07270000919918872),
#  (3, 0.2263143839580936),
#  (4, 0.6380464879110068),
#  (5, 0.060903690895697596),
#  (6, 0.050169938855455946),
#  (7, 0.12105864203693423),
#  (8, 0.49627756753866853),
#  (9, 0.08820290919186652),
#  (10, 0.15883065190689077),
#  (11, 0.14657483933458415),
#  (12, 0.04841519249890269),
#  (13, 0.10137137879666572),
#  (14, 0.147305012465708),
#  (15, 0.0775735862554975),
#  (16, 0.07012493718109294),
#  (17, 0.06920653107503927),
#  (18, 0.10457377484719263),
#  (19, 0.06983204044565798),
#  (20, 0.06851636490289492),
#  (21, 0.05682679653951866),
#  (22, 0.04749072638098378),
#  (23, 0.1281857057842942),
#  (24, 0.06922109885294067),
#  (25, 0.12773632883684785),
#  (26, 0.10047542276581711),
#  (27, 0.16367179739783014),
#  (28, 0.1704902553614631),
#  (29, 0.09929566125618666),
#  (30, 0.06153747314143853)]
# [(6, 0.12721761533342213),
#  (14, 0.12450877185332303),
#  (24, 0.17552628780755491),
#  (31, 0.1259702446088735),
#  (32, 0.14108334619770058),
#  (33, 0.34085455197506126),
#  (34, 0.30065149988386475),
#  (35, 0.13543623356425508),
#  (36, 0.16943195113597165),
#  (37, 0.1907542549564373),
#  (38, 0.14787704021190515),
#  (39, 0.269409250573251),
#  (40, 0.26131466499561706),
#  (41, 0.28968608555483816),
#  (42, 0.0655529399303793),
#  (43, 0.32738237977638684),
#  (44, 0.21416061469631587),
#  (45, 0.20541953856484735),
#  (46, 0.22471220314132456),
#  (47, 0.2675416681123928),
#  (48, 0.2084596550881552)]

# %% [markdown]
# # Modeling

# %%
lda_model =  gensim.models.LdaMulticore(tfidf_corpus, 
                                   num_topics = 8, 
                                   id2word = dictionary,                                    
                                   passes = 10,
                                   workers = 2)

# %%
for idx, topic in lda_model.print_topics(num_words=20):
    print("Topic: {} \nWords: {}".format(idx, topic ))
    print("\n")
# Out:
# Topic: 0
# Words: 0.007*"work" + 0.006*"sound" + 0.006*"bluetooth" + 0.005*"video" + 0.005*"camera" + 0.005*"imag" + 0.005*"headset" + 0.004*"batteri" + 0.004*"devic" + 0.004*"len" + 0.003*"price" + 0.003*"android" + 0.003*"headphon" + 0.003*"review" + 0.003*"seller" + 0.003*"best" + 0.003*"speaker" + 0.003*"smartphon" + 0.003*"connect" + 0.003*"product"
#
#
# Topic: 1
# Words: 0.013*"protect" + 0.008*"look" + 0.008*"nice" + 0.007*"like" + 0.007*"fit" + 0.006*"feel" + 0.006*"slim" + 0.006*"love" + 0.006*"button" + 0.006*"iphon" + 0.006*"color" + 0.006*"mount" + 0.006*"perfect" + 0.006*"drop" + 0.005*"review" + 0.005*"grip" + 0.005*"cover" + 0.005*"product" + 0.004*"best" + 0.004*"design"
#
#
# Topic: 2
# Words: 0.035*"love" + 0.031*"cute" + 0.019*"color" + 0.019*"nice" + 0.017*"pretti" + 0.016*"beauti" + 0.015*"look" + 0.014*"protect" + 0.012*"fit" + 0.011*"like" + 0.011*"perfect" + 0.010*"daughter" + 0.009*"cover" + 0.008*"price" + 0.008*"gift" + 0.008*"durabl" + 0.007*"iphon" + 0.007*"cheap" + 0.007*"super" + 0.007*"buy"
#
#
# Topic: 3
# Words: 0.039*"band" + 0.020*"watch" + 0.018*"clip" + 0.017*"holster" + 0.016*"belt" + 0.010*"armband" + 0.008*"break" + 0.008*"stand" + 0.008*"nice" + 0.008*"fit" + 0.007*"fitbit" + 0.007*"look" + 0.006*"comfort" + 0.006*"appl" + 0.006*"perfect" + 0.006*"qualiti" + 0.006*"love" + 0.006*"price" + 0.005*"work" + 0.005*"like"
#
#
# Topic: 4
# Words: 0.042*"screen" + 0.041*"protector" + 0.019*"glass" + 0.017*"instal" + 0.015*"easi" + 0.011*"bubbl" + 0.010*"appli" + 0.010*"product" + 0.009*"temper" + 0.009*"edg" + 0.008*"protect" + 0.007*"crack" + 0.006*"perfect" + 0.006*"work" + 0.006*"best" + 0.006*"stick" + 0.005*"clear" + 0.005*"selfi" + 0.005*"scratch" + 0.005*"cover"
#
#
# Topic: 5
# Words: 0.021*"work" + 0.020*"product" + 0.017*"excel" + 0.016*"perfect" + 0.014*"batteri" + 0.014*"price" + 0.013*"thank" + 0.011*"replac" + 0.011*"fast" + 0.011*"qualiti" + 0.010*"item" + 0.010*"love" + 0.010*"describ" + 0.009*"ship" + 0.009*"nice" + 0.008*"recommend" + 0.008*"money" + 0.008*"happi" + 0.008*"exact" + 0.008*"awesom"
#
#
# Topic: 6
# Words: 0.037*"wallet" + 0.033*"card" + 0.017*"leather" + 0.013*"magnet" + 0.012*"credit" + 0.011*"slot" + 0.011*"love" + 0.011*"hold" + 0.010*"carri" + 0.009*"nice" + 0.008*"purs" + 0.007*"qualiti" + 0.007*"strap" + 0.007*"like" + 0.006*"close" + 0.006*"look" + 0.006*"holder" + 0.006*"perfect" + 0.006*"pocket" + 0.005*"conveni"
#
#
# Topic: 7
# Words: 0.034*"charg" + 0.030*"charger" + 0.025*"cabl" + 0.016*"work" + 0.013*"batteri" + 0.011*"cord" + 0.011*"power" + 0.009*"fast" + 0.007*"devic" + 0.007*"port" + 0.006*"plug" + 0.006*"product" + 0.005*"long" + 0.005*"qualiti" + 0.005*"wireless" + 0.005*"quick" + 0.005*"bank" + 0.005*"light" + 0.004*"portabl" + 0.004*"need"

# %% [markdown]
# # Compute Model Perplexity and Coherence Score
#
# 'Perplexity' might not be the best measure to evaluate topic models because it doesn’t consider the context and semantic associations between words. This can be captured using 'Topic Coherence' measure.

# %%
## Compute Perplexity

from gensim.models import CoherenceModel

## Perplexity: Lower the better. Perplexity = exp(-1. * log-likelihood per word)
print('\nPerplexity: ', lda_model.log_perplexity(tfidf_corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=processed_docs, dictionary=dictionary, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -8.080376150372171
#
# Coherence Score:  0.42964011815376324

# %% [markdown]
# # Save the Model

# %%
# save model to disk (no need to use pickle module)
lda_model.save('lda_Multi.model')
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:252: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
# load trained model from file
trained_lda_Multi =  models.LdaMulticore.load('lda_Multi.model')
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:252: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
# # print all topics
# trained_lda_Multi.show_topics(num_topics=10,num_words=20)

# %%
# # print topics
# trained_lda_Multi.print_topic(0, topn=10)

# %%
# # another way
# for i in range(0, trained_lda_Multi.num_topics-1):
#     print(trained_lda_Multi.print_topic(i))

# %%
# # and another way, only prints top words
# for t in range(0, trained_lda_Multi.num_topics-1):
#     print('topic {}: '.format(t) + ', '.join([v[1] for v in trained_lda_Multi.show_topic(t, 20)]))

# %% [markdown]
# # Now Find the optimal number of topics for LDA
#
# To find optimal number of topics is, to build many LDA models with different values of number of topics (k) and pick the one that gives the highest coherence value.

# %%
#texts = processed_docs
def compute_coherence_values(dictionary, corpus, texts, limit, start=2, step=3):
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.LdaMulticore(corpus=corpus, num_topics=num_topics, id2word=dictionary)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

# %%
# Can take a long time to run.
model_list, coherence_values = compute_coherence_values(dictionary=dictionary, corpus=tfidf_corpus, texts=processed_docs, start=2, limit=40, step=6)

# %%
# Show graph
limit=40; start=2; step=6;
x = range(start, limit, step)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
# Out:
# Num Topics = 2  has Coherence Value of 0.3353
# Num Topics = 8  has Coherence Value of 0.4209
# Num Topics = 14  has Coherence Value of 0.4162
# Num Topics = 20  has Coherence Value of 0.4105
# Num Topics = 26  has Coherence Value of 0.3943
# Num Topics = 32  has Coherence Value of 0.3904
# Num Topics = 38  has Coherence Value of 0.3908

# %% [markdown]
# Based on the above score, 8 seems to be the best optimum number of topics to use for the model. It has the highest coherence score before flatening out.

# %%
# printing the best topics now 
optimal_model = model_list[1]
model_topics = optimal_model.show_topics(formatted=False)
pprint(optimal_model.print_topics(num_words=20))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-56be70824894> in <module>()
#       1 # printing the best topics now
# ----> 2 optimal_model = model_list[1]
#       3 model_topics = optimal_model.show_topics(formatted=False)
#       4 pprint(optimal_model.print_topics(num_words=20))
#
# NameError: name 'model_list' is not defined

# %% [markdown]
# # Finding the dominant topic in each sentence

# %%
def format_topics_sentences(ldamodel=trained_lda_Multi, corpus=tfidf_corpus, texts=processed_docs):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=trained_lda_Multi, corpus=tfidf_corpus, texts=processed_docs)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Review_Keywords', 'Original review']

# Show
df_dominant_topic.head(10)
# Out:
#    Document_No  ...                                    Original review
# 0            0  ...  [good, case, price, right, problem, lose, ston...
# 1            1  ...  [excit, case, love, color, feel, start, notic,...
# 2            2  ...  [good, item, star, good, deal, star, love, gre...
# 3            3  ...                    [thank, star, item, work, star]
# 4            4  ...  [great, charger, pretti, good, year, fit, phon...
# 5            5  ...  [fit, short, defin, recommend, price, right, c...
# 6            6  ...  [perfect, note, backup, charger, chage, samsun...
# 7            7  ...  [charger, specif, long, term, usag, plug, remo...
# 8            8  ...  [nice, case, print, start, fade, peel, use, st...
# 9            9  ...  [final, actual, work, samsung, note, charg, fa...
#
# [10 rows x 5 columns]

# %%
review_combine_final.head(2)
# Out:
#            IC  ...                                     Review_Combine
# 0  7508492919  ...  It is such a good case for a low price. I have...
# 1  7532385086  ...  I was very excited when I first got this case....
#
# [2 rows x 4 columns]

# %%
#df_dominant_topic['Original review'][0]

# %%
#df_dominant_topic['Review_Keywords'][0]

# %%
result_df = pd.concat([review_combine_final, df_dominant_topic], axis=1, join='inner')

# %%
result_df.head(2)
# Out:
#            IC  ...                                    Original review
# 0  7508492919  ...  [good, case, price, right, problem, lose, ston...
# 1  7532385086  ...  [excit, case, love, color, feel, start, notic,...
#
# [2 rows x 9 columns]

# %%
result_df = result_df[['IC','Review_Combine','Dominant_Topic','Topic_Perc_Contrib','Original review','Review_Keywords']]

# %%
result_df.head()
# Out:
#            IC  ...                                    Review_Keywords
# 0  7508492919  ...  love, cute, nice, color, look, protect, perfec...
# 1  7532385086  ...  love, cute, nice, color, look, protect, perfec...
# 2  7887421268  ...  love, cute, nice, color, look, protect, perfec...
# 3  8199900164  ...  love, cute, nice, color, look, protect, perfec...
# 4  8288853439  ...  charg, charger, cabl, work, batteri, cord, pow...
#
# [5 rows x 6 columns]

# %%
result_df.shape
# Out:
# (48134, 6)

# %% [markdown]
# **Find the most representative document for each topic**

# %%
# Group top 5 sentences under each topic
sent_topics_sorteddf_lda = pd.DataFrame()

sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_lda = pd.concat([sent_topics_sorteddf_lda, 
                                             grp.sort_values(['Perc_Contribution'], ascending=[0]).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf_lda.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf_lda.columns = ['Topic_Num', "Topic_Perc_Contrib", 'Review_Keywords', 'Original review']

# Show
sent_topics_sorteddf_lda.head()
# Out:
#    Topic_Num  ...                                    Original review
# 0        0.0  ...  [charger, junk, phone, plug, hour, charg, thin...
# 1        1.0  ...  [sorri, item, star, star, travel, dashboard, m...
# 2        2.0  ...  [case, steal, return, phone, secur, proper, is...
# 3        3.0  ...  [have, satisfi, owner, verizon, iphon, decid, ...
# 4        4.0  ...  [excel, product, work, recommend, good, produc...
#
# [5 rows x 4 columns]

# %% [markdown]
# # Make a submission

# %%
sent_topics_sorteddf_lda.to_csv('lda_Multi_submission.csv', index=False)
